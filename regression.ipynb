# %%
import random
from random import randint

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from keras.layers import Dense,LSTM, Concatenate, Input, Conv1D, Flatten, Dropout, BatchNormalization, GlobalAveragePooling1D, MaxPooling1D, GlobalAveragePooling1D, UpSampling1D, concatenate, Conv1DTranspose, Cropping1D, UpSampling1D, ZeroPadding1D, Reshape
from keras.models import Sequential,Model
from matplotlib.pyplot import legend
from sklearn.model_selection import train_test_split
from tensorflow.python.ops.linalg.linear_operator_algebra import inverse

from generator import Generator
from keras import metrics
import importlib

from inverse import fit_linear

tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from datasetLoader import *

# %%
def plot():
    plt.legend()
    plt.grid(True)
    plt.show()


def plot_loss(history):
    plt.plot(history.history['loss'], label='loss', marker=".")
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('Epoch')
    plt.ylabel('Error [MPG]')
    plot()

# %%
with open("data/initial kernels/Kernel_Silica_Adsorption.npy", 'rb') as f:
    data_sorb = np.load(f)
    data_sorb_tensor = tf.constant((data_sorb.T[87:]).T)
    data_sorb_tensor = tf.cast(data_sorb_tensor, tf.float32)

def custom_loss(y_true, y_pred):
    pass
    #print("data_sorb_tensor.shape = ", data_sorb_tensor.shape, y_pred[:,:128].shape)
    isotherm_from_distribution = tf.tensordot(y_pred[:,:128], data_sorb_tensor, axes=1)
    #print("isotherm_from_distribution = ", isotherm_from_distribution.shape, y_pred[:,128:].shape)
    return tf.reduce_sum(tf.square(y_pred[:,:128] - y_true[:,:128])) + 0*tf.reduce_sum(tf.square(y_pred[:,128:] - isotherm_from_distribution))


# np.ediff1d(pore_widths, to_begin=pore_widths[0])

# %%
import tensorflow as tf

class ConstrainedOutputLayer(tf.keras.layers.Layer):
    def __init__(self, M=None, weight=10, **kwargs):
        super(ConstrainedOutputLayer, self).__init__(**kwargs)
        # Initialize M as None to handle custom initialization in from_config
        if M is not None:
            self.M = tf.constant(M, dtype=tf.float32)
        else:
            self.M = None  # Will be set later during call or from_config
        self.weight = weight

    def call(self, y_out, x_in):
        if self.M is None:
            raise ValueError("Matrix M must be initialized.")
        # Apply the constraint logic
        constraint = tf.matmul(y_out, self.M) - x_in
        self.add_loss(self.weight * tf.reduce_mean(tf.square(constraint)))
        return y_out

    def get_config(self):
        # Get the base config and update it with custom arguments
        config = super(ConstrainedOutputLayer, self).get_config()
        # Serialize M as a list, and weight as is
        config.update({
            'M': self.M.numpy().tolist() if self.M is not None else None,
            'weight': self.weight
        })
        return config

    @classmethod
    def from_config(cls, config):
        # Reconstruct the layer from the config
        M = tf.constant(config['M'], dtype=tf.float32) if config['M'] is not None else None
        weight = config['weight']
        return cls(M=M, weight=weight)

# %%
def create_model(x):
    layer = []
    layer.append(Input(shape=x[0].shape))
    layer.append(Dense(200, activation='relu')(layer[-1]))
    layer.append(Dense(200, activation='relu')(layer[-1]))
    layer.append(Dense(200, activation='relu')(layer[-1]))
    layer.append(Dense(200, activation='relu')(layer[-1]))
    layer.append(Dense(128, activation='relu')(layer[-1]))
    layer.append(Dense(128, activation='relu')(layer[-1]))
    layer.append(Dense(128, activation='relu')(layer[-1]))
    layer.append(Dense(128, activation='relu')(layer[-1]))
    layer.append(Concatenate()([layer[-1], layer[0]]))
    model = tf.keras.Model(inputs=layer[0], outputs=layer[-1])
    model.compile(loss=custom_loss, optimizer='Adam')
    #model.compile(loss='mean_squared_error', optimizer='Adam')
    return model

def create_model_CNN_output():
    input_length = 371    # Длина входной последовательности
    output_length = 128   # Длина выходной последовательности
    feature_size = 1     # Количество признаков на каждом шаге (1 для одномерной последовательности)

    # === ЭНКОДЕР ===
    inputs = Input(shape=(input_length, feature_size))  # Входная последовательность
    x = Conv1D(16, kernel_size=3, activation='relu', padding='same')(inputs)  # Первый свёрточный слой
    x = Conv1D(32, kernel_size=3, activation='relu', padding='same')(x)  # Второй свёрточный слой
    x = GlobalAveragePooling1D()(x)  # Сжатие признаков (получаем скрытое представление)

    # === ПРОЕКЦИОННЫЙ СЛОЙ ===
    x = Dense(32, activation='relu')(x)  # Преобразование скрытого представления
    x = Dense(output_length * 64, activation='relu')(x)  # Подготовка к декодеру
    x = Reshape((output_length, 64))(x)  # Формирование "последовательности" для декодера

    # === ДЕКОДЕР ===
    x = Conv1DTranspose(64, kernel_size=3, activation='relu', padding='same')(x)  # Первый слой декодера
    x = Conv1DTranspose(32, kernel_size=3, activation='relu', padding='same')(x)  # Второй слой декодера
    outputs = Conv1D(1, kernel_size=1, activation='relu', padding='same')(x)  # Финальный слой

    # === МОДЕЛЬ ===
    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mse')
    return model

def create_model_CNN():
    inputs = Input(shape=(448, 1), name="Input")
    x = Conv1D(filters=8, kernel_size=3, activation='relu', padding='same', name="c1")(inputs)
    x = MaxPooling1D(pool_size=2, padding='same', name="p1")(x)
    x = BatchNormalization()(x)


    x = Conv1D(filters=16, kernel_size=3, activation='relu', padding='same', name="c2")(x)
    x = MaxPooling1D(pool_size=2, padding='same', name="p2")(x)
    x = BatchNormalization()(x)
    
    x = Conv1D(filters=32, kernel_size=3, activation='relu', padding='same', name="c3")(x)
    x = MaxPooling1D(pool_size=2, padding='same', name="p3")(x)
    x = BatchNormalization()(x)
    
    x = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same', name="c4")(x)
    x = MaxPooling1D(pool_size=2, padding='same', name="p4")(x)
    x = BatchNormalization()(x)
    
    x = Conv1D(filters=128, kernel_size=3, activation='relu', padding='same', name="c5")(x)
    x = MaxPooling1D(pool_size=2, padding='same', name="p5")(x)
    x = BatchNormalization()(x)
    
    x = Flatten(name="f1")(x)

    #DENSE OUTPUT
    x = Dense(128, activation='relu', name="d1")(x)
    x = BatchNormalization()(x)
    x = Dropout(0.15)(x)
    x = Dense(128, activation='relu', name="d2")(x)
    x = BatchNormalization()(x)
    x = Dropout(0.15)(x)
    x = Dense(128, activation='relu', name="d3")(x)
    #x = ConstrainedOutputLayer(M=data_sorb_tensor)(x, tf.squeeze(inputs, axis=-1))
    
    # input_for_loss = Reshape((371, ))(inputs)
    # outputs = Concatenate()([x, input_for_loss])
    
    #outputs = d3
    
    model = Model(inputs=[inputs], outputs=[x], name="CNN")
    #model.compile(loss='mean_squared_error', optimizer='Adam')
    model.compile(loss="mse", optimizer='Adam')
    return model

# %%
# with open("data/datasets/reports_best_tyhanov.npz", 'rb') as f:
#     dataset = np.load(f)
#     isotherm_data = dataset["isotherm_data"]
#     pore_distribution_data = dataset["pore_distribution_data"]
#     pore_widths = np.load("data/initial kernels/Size_Kernel_Silica_Adsorption.npy")

# %%
x_experimental, y_experimental = load_dataset('data/datasets/SMP_CUT_NOT_ZERO.npz')

x_experimental_QPS, y_experimental_QPS = load_dataset('data/datasets/reports.npz')

x_generated, y_generated = load_dataset('data/datasets/silica_random.npz')

# %%
x_train_exp, x_test_exp, y_train_exp, y_test_exp = train_test_split(x_experimental, y_experimental, test_size=0.15, random_state=1)
x_train_gen, x_test_gen, y_train_gen, y_test_gen = train_test_split(x_generated, y_generated, test_size=0.15, random_state=1)

# %%
with open(f'data/datasets/SMP_test.npz', "wb") as f:
    np.savez_compressed(f, x_train=x_train_exp, y_train=y_train_exp, x_test=x_test_exp, y_test=y_test_exp)

# %%
# x_train = np.concatenate((x_train_gen, x_train_exp), axis=0)
# x_test = np.concatenate((x_test_gen, x_test_exp), axis=0)
# y_train = np.concatenate((y_train_gen, y_train_exp), axis=0)
# y_test = np.concatenate((y_test_gen, y_test_exp), axis=0)

x_train, x_test, y_train, y_test = train_test_split(x_experimental, y_experimental, test_size=0.15, random_state=1)

# %%
model = create_model_CNN()
#model = create_model_CNN_output()
model.summary()
# Out:
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 448, 1)]          0
#
#  c1 (Conv1D)                 (None, 448, 8)            32
#
#  p1 (MaxPooling1D)           (None, 224, 8)            0
#
#  batch_normalization (BatchN  (None, 224, 8)           32
#  ormalization)
#
#  c2 (Conv1D)                 (None, 224, 16)           400
#
#  p2 (MaxPooling1D)           (None, 112, 16)           0
#
#  batch_normalization_1 (Batc  (None, 112, 16)          64
#  hNormalization)
#
#  c3 (Conv1D)                 (None, 112, 32)           1568
#
#  p3 (MaxPooling1D)           (None, 56, 32)            0
#
#  batch_normalization_2 (Batc  (None, 56, 32)           128
#  hNormalization)
#
#  c4 (Conv1D)                 (None, 56, 64)            6208
#
#  p4 (MaxPooling1D)           (None, 28, 64)            0
#
#  batch_normalization_3 (Batc  (None, 28, 64)           256
#  hNormalization)
#
#  c5 (Conv1D)                 (None, 28, 128)           24704
#
#  p5 (MaxPooling1D)           (None, 14, 128)           0
#
#  batch_normalization_4 (Batc  (None, 14, 128)          512
#  hNormalization)
#
#  f1 (Flatten)                (None, 1792)              0
#
#  d1 (Dense)                  (None, 128)               229504
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  d2 (Dense)                  (None, 128)               16512
#
#  batch_normalization_6 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  d3 (Dense)                  (None, 128)               16512
#
# =================================================================
# Total params: 297,456
# Trainable params: 296,448
# Non-trainable params: 1,008
# _________________________________________________________________

# %%
for layer in model.layers:
    layer.trainable = False
for i in range(11, 15):
    model.layers[i].trainable = True
for layer in model.layers:
    print(layer, layer.trainable)
model.summary()
# Out:
# <keras.engine.input_layer.InputLayer object at 0x000001F03BCCD4B0> False
# <keras.layers.convolutional.conv1d.Conv1D object at 0x000001F03B829EA0> False
# <keras.layers.pooling.max_pooling1d.MaxPooling1D object at 0x000001EEF68C62F0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F03DE0AFE0> False
# <keras.layers.convolutional.conv1d.Conv1D object at 0x000001F03DE0B910> False
# <keras.layers.pooling.max_pooling1d.MaxPooling1D object at 0x000001F03DE0B220> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F03DE0BD00> False
# <keras.layers.convolutional.conv1d.Conv1D object at 0x000001F03DE0AF20> False
# <keras.layers.pooling.max_pooling1d.MaxPooling1D object at 0x000001F03DE0AE30> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F03DE48A30> False
# <keras.layers.convolutional.conv1d.Conv1D object at 0x000001F03DE48AC0> False
# <keras.layers.pooling.max_pooling1d.MaxPooling1D object at 0x000001F03DE491B0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F03DE49690> True
# <keras.layers.convolutional.conv1d.Conv1D object at 0x000001F03DE49720> True
# <keras.layers.pooling.max_pooling1d.MaxPooling1D object at 0x000001F03DE49E10> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F03DE4A2F0> False
# <keras.layers.reshaping.flatten.Flatten object at 0x000001F03DE4A350> False
# <keras.layers.core.dense.Dense object at 0x000001F03DE4A920> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F03DE4A950> False
# <keras.layers.regularization.dropout.Dropout object at 0x000001F03DE4AD70> False
# <keras.layers.core.dense.Dense object at 0x000001F03DE4B460> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F03DE4B250> False
# <keras.layers.regularization.dropout.Dropout object at 0x000001F03DE4B7C0> False
# <keras.layers.core.dense.Dense object at 0x000001F03DE4BEB0> False
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 448, 1)]          0
#
#  c1 (Conv1D)                 (None, 448, 8)            32
#
#  p1 (MaxPooling1D)           (None, 224, 8)            0
#
#  batch_normalization_28 (Bat  (None, 224, 8)           32
#  chNormalization)
#
#  c2 (Conv1D)                 (None, 224, 16)           400
#
#  p2 (MaxPooling1D)           (None, 112, 16)           0
#
#  batch_normalization_29 (Bat  (None, 112, 16)          64
#  chNormalization)
#
#  c3 (Conv1D)                 (None, 112, 32)           1568
#
#  p3 (MaxPooling1D)           (None, 56, 32)            0
#
#  batch_normalization_30 (Bat  (None, 56, 32)           128
#  chNormalization)
#
#  c4 (Conv1D)                 (None, 56, 64)            6208
#
#  p4 (MaxPooling1D)           (None, 28, 64)            0
#
#  batch_normalization_31 (Bat  (None, 28, 64)           256
#  chNormalization)
#
#  c5 (Conv1D)                 (None, 28, 128)           24704
#
#  p5 (MaxPooling1D)           (None, 14, 128)           0
#
#  batch_normalization_32 (Bat  (None, 14, 128)          512
#  chNormalization)
#
#  f1 (Flatten)                (None, 1792)              0
#
#  d1 (Dense)                  (None, 128)               229504
#
#  batch_normalization_33 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  d2 (Dense)                  (None, 128)               16512
#
#  batch_normalization_34 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  d3 (Dense)                  (None, 128)               16512
#
# =================================================================
# Total params: 297,456
# Trainable params: 24,832
# Non-trainable params: 272,624
# _________________________________________________________________

# %%
# from keras import backend as K
# K.set_value(model.optimizer.learning_rate, 0.001)
model_name = "silica_CNN_cut_psd_exp.keras"
mcp_save = tf.keras.callbacks.ModelCheckpoint(filepath=f'data/models/{model_name}', save_best_only=True,
                                              monitor='val_loss', mode='min', verbose=1, save_weights_only=False,
                                              save_freq='epoch')

reduce_lr_loss = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                                                      patience=100, verbose=1, mode='auto')
history = model.fit(np.array(x_train), np.array(y_train),
                    epochs=1500, batch_size=1024, shuffle=True, verbose=2,
                    validation_data=(np.array(x_test), np.array(y_test)), callbacks=[mcp_save])
current_epoch = history.epoch[-1]
plot_loss(history)
# Out:
# Epoch 1/1500
#
# Epoch 1: val_loss improved from inf to 1.20195, saving model to data/models\silica_CNN_cut_psd_exp.keras
# 6/6 - 0s - loss: 0.0701 - val_loss: 1.2019 - 481ms/epoch - 80ms/step
# Epoch 2/1500
#
# Epoch 2: val_loss improved from 1.20195 to 1.07906, saving model to data/models\silica_CNN_cut_psd_exp.keras
# 6/6 - 0s - loss: 0.0717 - val_loss: 1.0791 - 180ms/epoch - 30ms/step
# Epoch 3/1500
#
# Epoch 3: val_loss did not improve from 1.07906
# 6/6 - 0s - loss: 0.0756 - val_loss: 1.4257 - 156ms/epoch - 26ms/step
# Epoch 4/1500
#
# Epoch 4: val_loss did not improve from 1.07906
# 6/6 - 0s - loss: 0.0686 - val_loss: 1.3540 - 141ms/epoch - 23ms/step
# Epoch 5/1500
#
# Epoch 5: val_loss did not improve from 1.07906
# 6/6 - 0s - loss: 0.0638 - val_loss: 1.3911 - 141ms/epoch - 23ms/step
# Epoch 6/1500
#
# Epoch 6: val_loss did not improve from 1.07906
# 6/6 - 0s - loss: 0.0653 - val_loss: 1.1962 - 156ms/epoch - 26ms/step
# Epoch 7/1500
#
# Epoch 7: val_loss did not improve from 1.07906
# 6/6 - 0s - loss: 0.0611 - val_loss: 1.3059 - 156ms/epoch - 26ms/step
# Epoch 8/1500
#
# Epoch 8: val_loss improved from 1.07906 to 0.87636, saving model to data/models\silica_CNN_cut_psd_exp.keras
# 6/6 - 0s - loss: 0.0612 - val_loss: 0.8764 - 188ms/epoch - 31ms/step
# Epoch 9/1500
#
# Epoch 9: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0735 - val_loss: 1.0916 - 148ms/epoch - 25ms/step
# Epoch 10/1500
#
# Epoch 10: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0658 - val_loss: 1.1213 - 156ms/epoch - 26ms/step
# Epoch 11/1500
#
# Epoch 11: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0818 - val_loss: 3.9312 - 141ms/epoch - 23ms/step
# Epoch 12/1500
#
# Epoch 12: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0820 - val_loss: 0.9811 - 141ms/epoch - 23ms/step
# Epoch 13/1500
#
# Epoch 13: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0951 - val_loss: 999.7081 - 156ms/epoch - 26ms/step
# Epoch 14/1500
#
# Epoch 14: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0860 - val_loss: 5493.7861 - 156ms/epoch - 26ms/step
# Epoch 15/1500
#
# Epoch 15: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0789 - val_loss: 48867.6055 - 157ms/epoch - 26ms/step
# Epoch 16/1500
#
# Epoch 16: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0887 - val_loss: 141012.8281 - 141ms/epoch - 23ms/step
# Epoch 17/1500
#
# Epoch 17: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0815 - val_loss: 439680.0312 - 156ms/epoch - 26ms/step
# Epoch 18/1500
#
# Epoch 18: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0954 - val_loss: 192868.9531 - 157ms/epoch - 26ms/step
# Epoch 19/1500
#
# Epoch 19: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0732 - val_loss: 7185.3447 - 141ms/epoch - 24ms/step
# Epoch 20/1500
#
# Epoch 20: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0798 - val_loss: 153215.0938 - 156ms/epoch - 26ms/step
# Epoch 21/1500
#
# Epoch 21: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0876 - val_loss: 12284.6074 - 156ms/epoch - 26ms/step
# Epoch 22/1500
#
# Epoch 22: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.1026 - val_loss: 1400.9147 - 143ms/epoch - 24ms/step
# Epoch 23/1500
#
# Epoch 23: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0780 - val_loss: 5030.6362 - 157ms/epoch - 26ms/step
# Epoch 24/1500
#
# Epoch 24: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0735 - val_loss: 20973.3516 - 156ms/epoch - 26ms/step
# Epoch 25/1500
#
# Epoch 25: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0798 - val_loss: 140778.1875 - 141ms/epoch - 23ms/step
# Epoch 26/1500
#
# Epoch 26: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0724 - val_loss: 6404.7041 - 163ms/epoch - 27ms/step
# Epoch 27/1500
#
# Epoch 27: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0729 - val_loss: 270.5231 - 141ms/epoch - 23ms/step
# Epoch 28/1500
#
# Epoch 28: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0958 - val_loss: 3.9717 - 141ms/epoch - 23ms/step
# Epoch 29/1500
#
# Epoch 29: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0733 - val_loss: 4.2402 - 158ms/epoch - 26ms/step
# Epoch 30/1500
#
# Epoch 30: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0903 - val_loss: 8750.8320 - 157ms/epoch - 26ms/step
# Epoch 31/1500
#
# Epoch 31: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0674 - val_loss: 96284.0938 - 141ms/epoch - 23ms/step
# Epoch 32/1500
#
# Epoch 32: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0671 - val_loss: 1747.4337 - 158ms/epoch - 26ms/step
# Epoch 33/1500
#
# Epoch 33: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0707 - val_loss: 20.6080 - 156ms/epoch - 26ms/step
# Epoch 34/1500
#
# Epoch 34: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0693 - val_loss: 1.7224 - 141ms/epoch - 23ms/step
# Epoch 35/1500
#
# Epoch 35: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0747 - val_loss: 1.1746 - 158ms/epoch - 26ms/step
# Epoch 36/1500
#
# Epoch 36: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0769 - val_loss: 1.0426 - 156ms/epoch - 26ms/step
# Epoch 37/1500
#
# Epoch 37: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0726 - val_loss: 1.1126 - 141ms/epoch - 23ms/step
# Epoch 38/1500
#
# Epoch 38: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0706 - val_loss: 191.7343 - 156ms/epoch - 26ms/step
# Epoch 39/1500
#
# Epoch 39: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0915 - val_loss: 2134.0173 - 156ms/epoch - 26ms/step
# Epoch 40/1500
#
# Epoch 40: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.1002 - val_loss: 2.7205 - 141ms/epoch - 23ms/step
# Epoch 41/1500
#
# Epoch 41: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0820 - val_loss: 99341.3750 - 156ms/epoch - 26ms/step
# Epoch 42/1500
#
# Epoch 42: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0744 - val_loss: 1.1267 - 143ms/epoch - 24ms/step
# Epoch 43/1500
#
# Epoch 43: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0759 - val_loss: 1.1261 - 157ms/epoch - 26ms/step
# Epoch 44/1500
#
# Epoch 44: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0677 - val_loss: 279.2557 - 141ms/epoch - 23ms/step
# Epoch 45/1500
#
# Epoch 45: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0687 - val_loss: 1.2683 - 157ms/epoch - 26ms/step
# Epoch 46/1500
#
# Epoch 46: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0712 - val_loss: 0.9195 - 156ms/epoch - 26ms/step
# Epoch 47/1500
#
# Epoch 47: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0674 - val_loss: 1.1636 - 141ms/epoch - 23ms/step
# Epoch 48/1500
#
# Epoch 48: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0668 - val_loss: 0.9887 - 156ms/epoch - 26ms/step
# Epoch 49/1500
#
# Epoch 49: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0711 - val_loss: 2.4770 - 160ms/epoch - 27ms/step
# Epoch 50/1500
#
# Epoch 50: val_loss did not improve from 0.87636
# 6/6 - 0s - loss: 0.0673 - val_loss: 1.0265 - 141ms/epoch - 23ms/step
# Epoch 51/1500
#
# Epoch 51: val_loss improved from 0.87636 to 0.83835, saving model to data/models\silica_CNN_cut_psd_exp.keras
# 6/6 - 0s - loss: 0.0619 - val_loss: 0.8384 - 188ms/epoch - 31ms/step
# Epoch 52/1500
#
# Epoch 52: val_loss improved from 0.83835 to 0.82770, saving model to data/models\silica_CNN_cut_psd_exp.keras
# 6/6 - 0s - loss: 0.0805 - val_loss: 0.8277 - 189ms/epoch - 31ms/step
# Epoch 53/1500
#
# Epoch 53: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0611 - val_loss: 0.9118 - 156ms/epoch - 26ms/step
# Epoch 54/1500
#
# Epoch 54: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0619 - val_loss: 1.3548 - 156ms/epoch - 26ms/step
# Epoch 55/1500
#
# Epoch 55: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0625 - val_loss: 0.9002 - 143ms/epoch - 24ms/step
# Epoch 56/1500
#
# Epoch 56: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0625 - val_loss: 3.0808 - 157ms/epoch - 26ms/step
# Epoch 57/1500
#
# Epoch 57: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0637 - val_loss: 414.5298 - 156ms/epoch - 26ms/step
# Epoch 58/1500
#
# Epoch 58: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0783 - val_loss: 201.8401 - 143ms/epoch - 24ms/step
# Epoch 59/1500
#
# Epoch 59: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0652 - val_loss: 1.5903 - 156ms/epoch - 26ms/step
# Epoch 60/1500
#
# Epoch 60: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0604 - val_loss: 129.3941 - 156ms/epoch - 26ms/step
# Epoch 61/1500
#
# Epoch 61: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0614 - val_loss: 2354.6809 - 141ms/epoch - 23ms/step
# Epoch 62/1500
#
# Epoch 62: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0654 - val_loss: 3443.8330 - 159ms/epoch - 27ms/step
# Epoch 63/1500
#
# Epoch 63: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0598 - val_loss: 27391.3047 - 141ms/epoch - 23ms/step
# Epoch 64/1500
#
# Epoch 64: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0618 - val_loss: 6692.4116 - 141ms/epoch - 23ms/step
# Epoch 65/1500
#
# Epoch 65: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0575 - val_loss: 9848.9678 - 160ms/epoch - 27ms/step
# Epoch 66/1500
#
# Epoch 66: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0683 - val_loss: 115048.6250 - 157ms/epoch - 26ms/step
# Epoch 67/1500
#
# Epoch 67: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0972 - val_loss: 189239.7812 - 156ms/epoch - 26ms/step
# Epoch 68/1500
#
# Epoch 68: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1384 - val_loss: 15429.0898 - 143ms/epoch - 24ms/step
# Epoch 69/1500
#
# Epoch 69: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1116 - val_loss: 328594.4688 - 156ms/epoch - 26ms/step
# Epoch 70/1500
#
# Epoch 70: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1033 - val_loss: 206313.5781 - 156ms/epoch - 26ms/step
# Epoch 71/1500
#
# Epoch 71: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1281 - val_loss: 550003.0625 - 143ms/epoch - 24ms/step
# Epoch 72/1500
#
# Epoch 72: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0828 - val_loss: 101449.6719 - 158ms/epoch - 26ms/step
# Epoch 73/1500
#
# Epoch 73: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1079 - val_loss: 582871.6875 - 156ms/epoch - 26ms/step
# Epoch 74/1500
#
# Epoch 74: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1143 - val_loss: 972550.2500 - 156ms/epoch - 26ms/step
# Epoch 75/1500
#
# Epoch 75: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1179 - val_loss: 1718972.6250 - 141ms/epoch - 23ms/step
# Epoch 76/1500
#
# Epoch 76: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1110 - val_loss: 2198195.7500 - 156ms/epoch - 26ms/step
# Epoch 77/1500
#
# Epoch 77: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0854 - val_loss: 538670.5000 - 156ms/epoch - 26ms/step
# Epoch 78/1500
#
# Epoch 78: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0936 - val_loss: 46401.8711 - 141ms/epoch - 24ms/step
# Epoch 79/1500
#
# Epoch 79: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0865 - val_loss: 39473.7812 - 157ms/epoch - 26ms/step
# Epoch 80/1500
#
# Epoch 80: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0915 - val_loss: 14.3054 - 156ms/epoch - 26ms/step
# Epoch 81/1500
#
# Epoch 81: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0784 - val_loss: 33.4772 - 141ms/epoch - 23ms/step
# Epoch 82/1500
#
# Epoch 82: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0708 - val_loss: 37.5718 - 159ms/epoch - 26ms/step
# Epoch 83/1500
#
# Epoch 83: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0777 - val_loss: 1.0321 - 156ms/epoch - 26ms/step
# Epoch 84/1500
#
# Epoch 84: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0682 - val_loss: 1.1948 - 141ms/epoch - 24ms/step
# Epoch 85/1500
#
# Epoch 85: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0741 - val_loss: 5.8673 - 146ms/epoch - 24ms/step
# Epoch 86/1500
#
# Epoch 86: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1086 - val_loss: 1.0550 - 141ms/epoch - 23ms/step
# Epoch 87/1500
#
# Epoch 87: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1288 - val_loss: 1.4963 - 156ms/epoch - 26ms/step
# Epoch 88/1500
#
# Epoch 88: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1072 - val_loss: 1.5497 - 143ms/epoch - 24ms/step
# Epoch 89/1500
#
# Epoch 89: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0908 - val_loss: 9.6294 - 156ms/epoch - 26ms/step
# Epoch 90/1500
#
# Epoch 90: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0988 - val_loss: 1.4077 - 141ms/epoch - 23ms/step
# Epoch 91/1500
#
# Epoch 91: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0924 - val_loss: 1.1090 - 156ms/epoch - 26ms/step
# Epoch 92/1500
#
# Epoch 92: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0881 - val_loss: 3.8855 - 143ms/epoch - 24ms/step
# Epoch 93/1500
#
# Epoch 93: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0858 - val_loss: 2719.5664 - 156ms/epoch - 26ms/step
# Epoch 94/1500
#
# Epoch 94: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0761 - val_loss: 1274.2905 - 156ms/epoch - 26ms/step
# Epoch 95/1500
#
# Epoch 95: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0959 - val_loss: 2502.1125 - 143ms/epoch - 24ms/step
# Epoch 96/1500
#
# Epoch 96: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0989 - val_loss: 48356.3438 - 164ms/epoch - 27ms/step
# Epoch 97/1500
#
# Epoch 97: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0690 - val_loss: 5957.0308 - 141ms/epoch - 23ms/step
# Epoch 98/1500
#
# Epoch 98: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0689 - val_loss: 4761.2612 - 159ms/epoch - 27ms/step
# Epoch 99/1500
#
# Epoch 99: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0699 - val_loss: 6327.7920 - 156ms/epoch - 26ms/step
# Epoch 100/1500
#
# Epoch 100: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0628 - val_loss: 2660.3896 - 141ms/epoch - 23ms/step
# Epoch 101/1500
#
# Epoch 101: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0649 - val_loss: 234.4281 - 156ms/epoch - 26ms/step
# Epoch 102/1500
#
# Epoch 102: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0613 - val_loss: 42.2057 - 160ms/epoch - 27ms/step
# Epoch 103/1500
#
# Epoch 103: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0734 - val_loss: 1.3816 - 144ms/epoch - 24ms/step
# Epoch 104/1500
#
# Epoch 104: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0622 - val_loss: 68.8201 - 156ms/epoch - 26ms/step
# Epoch 105/1500
#
# Epoch 105: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0622 - val_loss: 2894.3684 - 159ms/epoch - 27ms/step
# Epoch 106/1500
#
# Epoch 106: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0666 - val_loss: 3412.1409 - 141ms/epoch - 23ms/step
# Epoch 107/1500
#
# Epoch 107: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0705 - val_loss: 13684.1357 - 156ms/epoch - 26ms/step
# Epoch 108/1500
#
# Epoch 108: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0631 - val_loss: 2355.5352 - 157ms/epoch - 26ms/step
# Epoch 109/1500
#
# Epoch 109: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0786 - val_loss: 6.3106 - 156ms/epoch - 26ms/step
# Epoch 110/1500
#
# Epoch 110: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0685 - val_loss: 26.5790 - 141ms/epoch - 23ms/step
# Epoch 111/1500
#
# Epoch 111: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0643 - val_loss: 9.5643 - 153ms/epoch - 25ms/step
# Epoch 112/1500
#
# Epoch 112: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0624 - val_loss: 1.8764 - 159ms/epoch - 26ms/step
# Epoch 113/1500
#
# Epoch 113: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0717 - val_loss: 25.2837 - 141ms/epoch - 23ms/step
# Epoch 114/1500
#
# Epoch 114: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0626 - val_loss: 15.7754 - 141ms/epoch - 23ms/step
# Epoch 115/1500
#
# Epoch 115: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0670 - val_loss: 1.7666 - 147ms/epoch - 25ms/step
# Epoch 116/1500
#
# Epoch 116: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0642 - val_loss: 1.7201 - 141ms/epoch - 23ms/step
# Epoch 117/1500
#
# Epoch 117: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0652 - val_loss: 1.5914 - 156ms/epoch - 26ms/step
# Epoch 118/1500
#
# Epoch 118: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0601 - val_loss: 1.6251 - 156ms/epoch - 26ms/step
# Epoch 119/1500
#
# Epoch 119: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0636 - val_loss: 1.5850 - 141ms/epoch - 23ms/step
# Epoch 120/1500
#
# Epoch 120: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0711 - val_loss: 1.6971 - 156ms/epoch - 26ms/step
# Epoch 121/1500
#
# Epoch 121: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0640 - val_loss: 1.6967 - 156ms/epoch - 26ms/step
# Epoch 122/1500
#
# Epoch 122: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0627 - val_loss: 1.3657 - 143ms/epoch - 24ms/step
# Epoch 123/1500
#
# Epoch 123: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0579 - val_loss: 1.1714 - 156ms/epoch - 26ms/step
# Epoch 124/1500
#
# Epoch 124: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0701 - val_loss: 1.1796 - 156ms/epoch - 26ms/step
# Epoch 125/1500
#
# Epoch 125: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0616 - val_loss: 1.2480 - 143ms/epoch - 24ms/step
# Epoch 126/1500
#
# Epoch 126: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0615 - val_loss: 1.5014 - 156ms/epoch - 26ms/step
# Epoch 127/1500
#
# Epoch 127: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0584 - val_loss: 1.6051 - 157ms/epoch - 26ms/step
# Epoch 128/1500
#
# Epoch 128: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0590 - val_loss: 1.1912 - 142ms/epoch - 24ms/step
# Epoch 129/1500
#
# Epoch 129: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0738 - val_loss: 1.4028 - 156ms/epoch - 26ms/step
# Epoch 130/1500
#
# Epoch 130: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0794 - val_loss: 0.8846 - 156ms/epoch - 26ms/step
# Epoch 131/1500
#
# Epoch 131: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0839 - val_loss: 2518.6572 - 141ms/epoch - 23ms/step
# Epoch 132/1500
#
# Epoch 132: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0799 - val_loss: 22734.2852 - 141ms/epoch - 24ms/step
# Epoch 133/1500
#
# Epoch 133: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0641 - val_loss: 25833.5859 - 156ms/epoch - 26ms/step
# Epoch 134/1500
#
# Epoch 134: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0670 - val_loss: 65901.8281 - 141ms/epoch - 23ms/step
# Epoch 135/1500
#
# Epoch 135: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0602 - val_loss: 64008.5078 - 160ms/epoch - 27ms/step
# Epoch 136/1500
#
# Epoch 136: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0582 - val_loss: 19394.7207 - 141ms/epoch - 23ms/step
# Epoch 137/1500
#
# Epoch 137: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0626 - val_loss: 17409.7754 - 156ms/epoch - 26ms/step
# Epoch 138/1500
#
# Epoch 138: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0727 - val_loss: 32877.6797 - 144ms/epoch - 24ms/step
# Epoch 139/1500
#
# Epoch 139: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0623 - val_loss: 61422.3633 - 141ms/epoch - 23ms/step
# Epoch 140/1500
#
# Epoch 140: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0617 - val_loss: 81018.3750 - 156ms/epoch - 26ms/step
# Epoch 141/1500
#
# Epoch 141: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0657 - val_loss: 63050.6328 - 157ms/epoch - 26ms/step
# Epoch 142/1500
#
# Epoch 142: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0616 - val_loss: 113374.8516 - 143ms/epoch - 24ms/step
# Epoch 143/1500
#
# Epoch 143: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0612 - val_loss: 48676.0430 - 156ms/epoch - 26ms/step
# Epoch 144/1500
#
# Epoch 144: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0619 - val_loss: 13026.1758 - 143ms/epoch - 24ms/step
# Epoch 145/1500
#
# Epoch 145: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0684 - val_loss: 15129.9766 - 158ms/epoch - 26ms/step
# Epoch 146/1500
#
# Epoch 146: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0605 - val_loss: 4740.9604 - 156ms/epoch - 26ms/step
# Epoch 147/1500
#
# Epoch 147: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0603 - val_loss: 9808.8447 - 141ms/epoch - 23ms/step
# Epoch 148/1500
#
# Epoch 148: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0650 - val_loss: 45692.8281 - 158ms/epoch - 26ms/step
# Epoch 149/1500
#
# Epoch 149: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0610 - val_loss: 34764.3828 - 156ms/epoch - 26ms/step
# Epoch 150/1500
#
# Epoch 150: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0651 - val_loss: 7154.8569 - 141ms/epoch - 23ms/step
# Epoch 151/1500
#
# Epoch 151: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0605 - val_loss: 1.5329 - 157ms/epoch - 26ms/step
# Epoch 152/1500
#
# Epoch 152: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0640 - val_loss: 2.5404 - 145ms/epoch - 24ms/step
# Epoch 153/1500
#
# Epoch 153: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0595 - val_loss: 2.2750 - 141ms/epoch - 23ms/step
# Epoch 154/1500
#
# Epoch 154: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0651 - val_loss: 1.2981 - 156ms/epoch - 26ms/step
# Epoch 155/1500
#
# Epoch 155: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0584 - val_loss: 1.7147 - 143ms/epoch - 24ms/step
# Epoch 156/1500
#
# Epoch 156: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0741 - val_loss: 1.4995 - 156ms/epoch - 26ms/step
# Epoch 157/1500
#
# Epoch 157: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0584 - val_loss: 1.0700 - 156ms/epoch - 26ms/step
# Epoch 158/1500
#
# Epoch 158: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0602 - val_loss: 1.9230 - 142ms/epoch - 24ms/step
# Epoch 159/1500
#
# Epoch 159: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0646 - val_loss: 1.5377 - 157ms/epoch - 26ms/step
# Epoch 160/1500
#
# Epoch 160: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0629 - val_loss: 1.7721 - 157ms/epoch - 26ms/step
# Epoch 161/1500
#
# Epoch 161: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0774 - val_loss: 1.5510 - 141ms/epoch - 23ms/step
# Epoch 162/1500
#
# Epoch 162: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0616 - val_loss: 1.3196 - 142ms/epoch - 24ms/step
# Epoch 163/1500
#
# Epoch 163: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0620 - val_loss: 1.5063 - 141ms/epoch - 23ms/step
# Epoch 164/1500
#
# Epoch 164: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0616 - val_loss: 1.4984 - 141ms/epoch - 23ms/step
# Epoch 165/1500
#
# Epoch 165: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0597 - val_loss: 1.7563 - 157ms/epoch - 26ms/step
# Epoch 166/1500
#
# Epoch 166: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0690 - val_loss: 1.7535 - 141ms/epoch - 23ms/step
# Epoch 167/1500
#
# Epoch 167: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0655 - val_loss: 1.4055 - 141ms/epoch - 23ms/step
# Epoch 168/1500
#
# Epoch 168: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0767 - val_loss: 2.8131 - 157ms/epoch - 26ms/step
# Epoch 169/1500
#
# Epoch 169: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0644 - val_loss: 53.7542 - 157ms/epoch - 26ms/step
# Epoch 170/1500
#
# Epoch 170: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0796 - val_loss: 511.0183 - 141ms/epoch - 23ms/step
# Epoch 171/1500
#
# Epoch 171: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0760 - val_loss: 1.5303 - 156ms/epoch - 26ms/step
# Epoch 172/1500
#
# Epoch 172: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0727 - val_loss: 1.1097 - 144ms/epoch - 24ms/step
# Epoch 173/1500
#
# Epoch 173: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0710 - val_loss: 2.5197 - 141ms/epoch - 23ms/step
# Epoch 174/1500
#
# Epoch 174: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0658 - val_loss: 2.6423 - 156ms/epoch - 26ms/step
# Epoch 175/1500
#
# Epoch 175: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0596 - val_loss: 0.8961 - 157ms/epoch - 26ms/step
# Epoch 176/1500
#
# Epoch 176: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0586 - val_loss: 0.9772 - 141ms/epoch - 23ms/step
# Epoch 177/1500
#
# Epoch 177: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0615 - val_loss: 1.1011 - 156ms/epoch - 26ms/step
# Epoch 178/1500
#
# Epoch 178: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0628 - val_loss: 2.4641 - 159ms/epoch - 26ms/step
# Epoch 179/1500
#
# Epoch 179: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0631 - val_loss: 1.7750 - 141ms/epoch - 23ms/step
# Epoch 180/1500
#
# Epoch 180: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0680 - val_loss: 1.1759 - 156ms/epoch - 26ms/step
# Epoch 181/1500
#
# Epoch 181: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0599 - val_loss: 1.6806 - 141ms/epoch - 23ms/step
# Epoch 182/1500
#
# Epoch 182: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0582 - val_loss: 1.7317 - 141ms/epoch - 23ms/step
# Epoch 183/1500
#
# Epoch 183: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0626 - val_loss: 1.3517 - 156ms/epoch - 26ms/step
# Epoch 184/1500
#
# Epoch 184: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0713 - val_loss: 1.4028 - 156ms/epoch - 26ms/step
# Epoch 185/1500
#
# Epoch 185: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0616 - val_loss: 1.2089 - 142ms/epoch - 24ms/step
# Epoch 186/1500
#
# Epoch 186: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0644 - val_loss: 1.4255 - 141ms/epoch - 23ms/step
# Epoch 187/1500
#
# Epoch 187: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0639 - val_loss: 0.9449 - 157ms/epoch - 26ms/step
# Epoch 188/1500
#
# Epoch 188: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0595 - val_loss: 1.7829 - 158ms/epoch - 26ms/step
# Epoch 189/1500
#
# Epoch 189: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0589 - val_loss: 1.1364 - 141ms/epoch - 23ms/step
# Epoch 190/1500
#
# Epoch 190: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0582 - val_loss: 1.2818 - 156ms/epoch - 26ms/step
# Epoch 191/1500
#
# Epoch 191: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0568 - val_loss: 26.3196 - 141ms/epoch - 23ms/step
# Epoch 192/1500
#
# Epoch 192: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0673 - val_loss: 30.6500 - 160ms/epoch - 27ms/step
# Epoch 193/1500
#
# Epoch 193: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0599 - val_loss: 217.0469 - 157ms/epoch - 26ms/step
# Epoch 194/1500
#
# Epoch 194: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0597 - val_loss: 41.0384 - 141ms/epoch - 23ms/step
# Epoch 195/1500
#
# Epoch 195: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0607 - val_loss: 1566.6427 - 163ms/epoch - 27ms/step
# Epoch 196/1500
#
# Epoch 196: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0681 - val_loss: 81.3929 - 141ms/epoch - 23ms/step
# Epoch 197/1500
#
# Epoch 197: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0602 - val_loss: 30.0256 - 141ms/epoch - 23ms/step
# Epoch 198/1500
#
# Epoch 198: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0654 - val_loss: 13.1799 - 158ms/epoch - 26ms/step
# Epoch 199/1500
#
# Epoch 199: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0612 - val_loss: 58.9902 - 157ms/epoch - 26ms/step
# Epoch 200/1500
#
# Epoch 200: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0627 - val_loss: 48.0736 - 141ms/epoch - 23ms/step
# Epoch 201/1500
#
# Epoch 201: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0614 - val_loss: 152.8593 - 156ms/epoch - 26ms/step
# Epoch 202/1500
#
# Epoch 202: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0588 - val_loss: 176.0668 - 158ms/epoch - 26ms/step
# Epoch 203/1500
#
# Epoch 203: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0573 - val_loss: 72.6757 - 156ms/epoch - 26ms/step
# Epoch 204/1500
#
# Epoch 204: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0597 - val_loss: 11.3446 - 141ms/epoch - 23ms/step
# Epoch 205/1500
#
# Epoch 205: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0588 - val_loss: 409.2856 - 157ms/epoch - 26ms/step
# Epoch 206/1500
#
# Epoch 206: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0641 - val_loss: 9.9778 - 157ms/epoch - 26ms/step
# Epoch 207/1500
#
# Epoch 207: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0628 - val_loss: 1.8156 - 141ms/epoch - 24ms/step
# Epoch 208/1500
#
# Epoch 208: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0704 - val_loss: 0.9938 - 161ms/epoch - 27ms/step
# Epoch 209/1500
#
# Epoch 209: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0604 - val_loss: 1.2153 - 141ms/epoch - 23ms/step
# Epoch 210/1500
#
# Epoch 210: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0643 - val_loss: 1.0399 - 156ms/epoch - 26ms/step
# Epoch 211/1500
#
# Epoch 211: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0592 - val_loss: 1.3761 - 157ms/epoch - 26ms/step
# Epoch 212/1500
#
# Epoch 212: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0557 - val_loss: 1.3758 - 157ms/epoch - 26ms/step
# Epoch 213/1500
#
# Epoch 213: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0617 - val_loss: 1.0120 - 145ms/epoch - 24ms/step
# Epoch 214/1500
#
# Epoch 214: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0628 - val_loss: 9.6945 - 156ms/epoch - 26ms/step
# Epoch 215/1500
#
# Epoch 215: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0592 - val_loss: 2.9591 - 156ms/epoch - 26ms/step
# Epoch 216/1500
#
# Epoch 216: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0605 - val_loss: 1.0144 - 157ms/epoch - 26ms/step
# Epoch 217/1500
#
# Epoch 217: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0569 - val_loss: 1.3298 - 141ms/epoch - 23ms/step
# Epoch 218/1500
#
# Epoch 218: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0653 - val_loss: 29.2492 - 159ms/epoch - 26ms/step
# Epoch 219/1500
#
# Epoch 219: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0704 - val_loss: 44.8070 - 141ms/epoch - 23ms/step
# Epoch 220/1500
#
# Epoch 220: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0643 - val_loss: 1.2075 - 141ms/epoch - 24ms/step
# Epoch 221/1500
#
# Epoch 221: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0757 - val_loss: 1.1038 - 156ms/epoch - 26ms/step
# Epoch 222/1500
#
# Epoch 222: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0708 - val_loss: 1.0510 - 156ms/epoch - 26ms/step
# Epoch 223/1500
#
# Epoch 223: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0629 - val_loss: 1.4445 - 141ms/epoch - 23ms/step
# Epoch 224/1500
#
# Epoch 224: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0666 - val_loss: 1.7395 - 156ms/epoch - 26ms/step
# Epoch 225/1500
#
# Epoch 225: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0722 - val_loss: 2.0205 - 143ms/epoch - 24ms/step
# Epoch 226/1500
#
# Epoch 226: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0623 - val_loss: 1.5198 - 157ms/epoch - 26ms/step
# Epoch 227/1500
#
# Epoch 227: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0577 - val_loss: 1.3859 - 141ms/epoch - 23ms/step
# Epoch 228/1500
#
# Epoch 228: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0632 - val_loss: 1.5985 - 160ms/epoch - 27ms/step
# Epoch 229/1500
#
# Epoch 229: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0769 - val_loss: 105.2064 - 141ms/epoch - 23ms/step
# Epoch 230/1500
#
# Epoch 230: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0744 - val_loss: 396.4688 - 157ms/epoch - 26ms/step
# Epoch 231/1500
#
# Epoch 231: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0990 - val_loss: 1774.3921 - 156ms/epoch - 26ms/step
# Epoch 232/1500
#
# Epoch 232: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0959 - val_loss: 775.1225 - 152ms/epoch - 25ms/step
# Epoch 233/1500
#
# Epoch 233: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1063 - val_loss: 72296.3359 - 141ms/epoch - 23ms/step
# Epoch 234/1500
#
# Epoch 234: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1511 - val_loss: 56733.1680 - 157ms/epoch - 26ms/step
# Epoch 235/1500
#
# Epoch 235: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.2098 - val_loss: 332883.8438 - 158ms/epoch - 26ms/step
# Epoch 236/1500
#
# Epoch 236: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.2350 - val_loss: 57205.3125 - 156ms/epoch - 26ms/step
# Epoch 237/1500
#
# Epoch 237: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.2071 - val_loss: 10734.8008 - 141ms/epoch - 23ms/step
# Epoch 238/1500
#
# Epoch 238: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1467 - val_loss: 2.7119 - 158ms/epoch - 26ms/step
# Epoch 239/1500
#
# Epoch 239: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1509 - val_loss: 97.5490 - 141ms/epoch - 23ms/step
# Epoch 240/1500
#
# Epoch 240: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1520 - val_loss: 2.1987 - 156ms/epoch - 26ms/step
# Epoch 241/1500
#
# Epoch 241: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1470 - val_loss: 401333.0000 - 141ms/epoch - 23ms/step
# Epoch 242/1500
#
# Epoch 242: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1753 - val_loss: 17108.2402 - 158ms/epoch - 26ms/step
# Epoch 243/1500
#
# Epoch 243: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1325 - val_loss: 1.3767 - 156ms/epoch - 26ms/step
# Epoch 244/1500
#
# Epoch 244: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1032 - val_loss: 1073.5918 - 141ms/epoch - 23ms/step
# Epoch 245/1500
#
# Epoch 245: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1130 - val_loss: 13.7861 - 142ms/epoch - 24ms/step
# Epoch 246/1500
#
# Epoch 246: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0924 - val_loss: 24.6493 - 156ms/epoch - 26ms/step
# Epoch 247/1500
#
# Epoch 247: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0823 - val_loss: 31.6371 - 157ms/epoch - 26ms/step
# Epoch 248/1500
#
# Epoch 248: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0863 - val_loss: 10.2139 - 141ms/epoch - 23ms/step
# Epoch 249/1500
#
# Epoch 249: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0784 - val_loss: 1.3002 - 156ms/epoch - 26ms/step
# Epoch 250/1500
#
# Epoch 250: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0788 - val_loss: 1.4288 - 156ms/epoch - 26ms/step
# Epoch 251/1500
#
# Epoch 251: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0668 - val_loss: 1.8107 - 156ms/epoch - 26ms/step
# Epoch 252/1500
#
# Epoch 252: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0624 - val_loss: 1.7942 - 141ms/epoch - 23ms/step
# Epoch 253/1500
#
# Epoch 253: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0676 - val_loss: 1.7776 - 141ms/epoch - 23ms/step
# Epoch 254/1500
#
# Epoch 254: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0717 - val_loss: 1.4944 - 156ms/epoch - 26ms/step
# Epoch 255/1500
#
# Epoch 255: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0718 - val_loss: 1.4642 - 158ms/epoch - 26ms/step
# Epoch 256/1500
#
# Epoch 256: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0733 - val_loss: 1.2097 - 141ms/epoch - 23ms/step
# Epoch 257/1500
#
# Epoch 257: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0719 - val_loss: 0.8503 - 141ms/epoch - 23ms/step
# Epoch 258/1500
#
# Epoch 258: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0661 - val_loss: 1.2898 - 156ms/epoch - 26ms/step
# Epoch 259/1500
#
# Epoch 259: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0943 - val_loss: 123.3531 - 153ms/epoch - 26ms/step
# Epoch 260/1500
#
# Epoch 260: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0807 - val_loss: 173.8161 - 156ms/epoch - 26ms/step
# Epoch 261/1500
#
# Epoch 261: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0718 - val_loss: 2.1121 - 141ms/epoch - 24ms/step
# Epoch 262/1500
#
# Epoch 262: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0733 - val_loss: 2.7160 - 141ms/epoch - 23ms/step
# Epoch 263/1500
#
# Epoch 263: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0703 - val_loss: 708.0834 - 156ms/epoch - 26ms/step
# Epoch 264/1500
#
# Epoch 264: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0787 - val_loss: 2834.2288 - 156ms/epoch - 26ms/step
# Epoch 265/1500
#
# Epoch 265: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0667 - val_loss: 1.2623 - 158ms/epoch - 26ms/step
# Epoch 266/1500
#
# Epoch 266: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0882 - val_loss: 2.0295 - 141ms/epoch - 23ms/step
# Epoch 267/1500
#
# Epoch 267: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0740 - val_loss: 1483.5946 - 156ms/epoch - 26ms/step
# Epoch 268/1500
#
# Epoch 268: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0711 - val_loss: 471.4125 - 156ms/epoch - 26ms/step
# Epoch 269/1500
#
# Epoch 269: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0661 - val_loss: 2.9511 - 156ms/epoch - 26ms/step
# Epoch 270/1500
#
# Epoch 270: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0637 - val_loss: 294.3367 - 156ms/epoch - 26ms/step
# Epoch 271/1500
#
# Epoch 271: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0659 - val_loss: 2763.0464 - 151ms/epoch - 25ms/step
# Epoch 272/1500
#
# Epoch 272: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0702 - val_loss: 198.3743 - 141ms/epoch - 23ms/step
# Epoch 273/1500
#
# Epoch 273: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0614 - val_loss: 1443.6459 - 159ms/epoch - 26ms/step
# Epoch 274/1500
#
# Epoch 274: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0613 - val_loss: 56495.9258 - 141ms/epoch - 23ms/step
# Epoch 275/1500
#
# Epoch 275: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0669 - val_loss: 66111.1172 - 141ms/epoch - 23ms/step
# Epoch 276/1500
#
# Epoch 276: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0608 - val_loss: 50905.1719 - 154ms/epoch - 26ms/step
# Epoch 277/1500
#
# Epoch 277: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0735 - val_loss: 21934.6133 - 156ms/epoch - 26ms/step
# Epoch 278/1500
#
# Epoch 278: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0701 - val_loss: 1041.4242 - 141ms/epoch - 23ms/step
# Epoch 279/1500
#
# Epoch 279: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0662 - val_loss: 20.5304 - 157ms/epoch - 26ms/step
# Epoch 280/1500
#
# Epoch 280: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0755 - val_loss: 9330.9443 - 156ms/epoch - 26ms/step
# Epoch 281/1500
#
# Epoch 281: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0707 - val_loss: 202100.6562 - 156ms/epoch - 26ms/step
# Epoch 282/1500
#
# Epoch 282: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0649 - val_loss: 490618.0312 - 142ms/epoch - 24ms/step
# Epoch 283/1500
#
# Epoch 283: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0674 - val_loss: 429729.7500 - 156ms/epoch - 26ms/step
# Epoch 284/1500
#
# Epoch 284: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0647 - val_loss: 118272.1641 - 156ms/epoch - 26ms/step
# Epoch 285/1500
#
# Epoch 285: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0595 - val_loss: 91033.1641 - 156ms/epoch - 26ms/step
# Epoch 286/1500
#
# Epoch 286: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0636 - val_loss: 32786.8750 - 141ms/epoch - 23ms/step
# Epoch 287/1500
#
# Epoch 287: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0603 - val_loss: 43435.4688 - 156ms/epoch - 26ms/step
# Epoch 288/1500
#
# Epoch 288: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0598 - val_loss: 35190.1875 - 156ms/epoch - 26ms/step
# Epoch 289/1500
#
# Epoch 289: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0675 - val_loss: 56387.3906 - 142ms/epoch - 24ms/step
# Epoch 290/1500
#
# Epoch 290: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0626 - val_loss: 165587.2500 - 157ms/epoch - 26ms/step
# Epoch 291/1500
#
# Epoch 291: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0604 - val_loss: 209667.8906 - 141ms/epoch - 23ms/step
# Epoch 292/1500
#
# Epoch 292: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0646 - val_loss: 316000.0000 - 142ms/epoch - 24ms/step
# Epoch 293/1500
#
# Epoch 293: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0769 - val_loss: 385286.4688 - 157ms/epoch - 26ms/step
# Epoch 294/1500
#
# Epoch 294: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0629 - val_loss: 669535.9375 - 156ms/epoch - 26ms/step
# Epoch 295/1500
#
# Epoch 295: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0607 - val_loss: 434560.2500 - 141ms/epoch - 23ms/step
# Epoch 296/1500
#
# Epoch 296: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0663 - val_loss: 295944.5938 - 157ms/epoch - 26ms/step
# Epoch 297/1500
#
# Epoch 297: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0729 - val_loss: 277360.6250 - 156ms/epoch - 26ms/step
# Epoch 298/1500
#
# Epoch 298: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0690 - val_loss: 194910.6875 - 141ms/epoch - 24ms/step
# Epoch 299/1500
#
# Epoch 299: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0652 - val_loss: 121974.0000 - 158ms/epoch - 26ms/step
# Epoch 300/1500
#
# Epoch 300: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0634 - val_loss: 202469.4062 - 156ms/epoch - 26ms/step
# Epoch 301/1500
#
# Epoch 301: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0624 - val_loss: 181475.3125 - 141ms/epoch - 23ms/step
# Epoch 302/1500
#
# Epoch 302: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0629 - val_loss: 152048.9375 - 143ms/epoch - 24ms/step
# Epoch 303/1500
#
# Epoch 303: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0585 - val_loss: 77502.2969 - 156ms/epoch - 26ms/step
# Epoch 304/1500
#
# Epoch 304: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0673 - val_loss: 217198.0469 - 142ms/epoch - 24ms/step
# Epoch 305/1500
#
# Epoch 305: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0626 - val_loss: 315837.8438 - 141ms/epoch - 23ms/step
# Epoch 306/1500
#
# Epoch 306: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0600 - val_loss: 414613.5938 - 158ms/epoch - 26ms/step
# Epoch 307/1500
#
# Epoch 307: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0533 - val_loss: 319739.2188 - 156ms/epoch - 26ms/step
# Epoch 308/1500
#
# Epoch 308: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0602 - val_loss: 303699.1562 - 141ms/epoch - 23ms/step
# Epoch 309/1500
#
# Epoch 309: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0642 - val_loss: 242773.5781 - 157ms/epoch - 26ms/step
# Epoch 310/1500
#
# Epoch 310: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0633 - val_loss: 174449.0000 - 157ms/epoch - 26ms/step
# Epoch 311/1500
#
# Epoch 311: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0601 - val_loss: 73927.1953 - 141ms/epoch - 23ms/step
# Epoch 312/1500
#
# Epoch 312: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0670 - val_loss: 136293.8750 - 158ms/epoch - 26ms/step
# Epoch 313/1500
#
# Epoch 313: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0613 - val_loss: 129073.7422 - 157ms/epoch - 26ms/step
# Epoch 314/1500
#
# Epoch 314: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0606 - val_loss: 67044.0000 - 141ms/epoch - 23ms/step
# Epoch 315/1500
#
# Epoch 315: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0698 - val_loss: 7981.6865 - 141ms/epoch - 24ms/step
# Epoch 316/1500
#
# Epoch 316: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0708 - val_loss: 2972.1387 - 156ms/epoch - 26ms/step
# Epoch 317/1500
#
# Epoch 317: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0704 - val_loss: 263991.6875 - 157ms/epoch - 26ms/step
# Epoch 318/1500
#
# Epoch 318: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0863 - val_loss: 1.1038 - 141ms/epoch - 23ms/step
# Epoch 319/1500
#
# Epoch 319: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0891 - val_loss: 6.1602 - 144ms/epoch - 24ms/step
# Epoch 320/1500
#
# Epoch 320: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1037 - val_loss: 2.2115 - 157ms/epoch - 26ms/step
# Epoch 321/1500
#
# Epoch 321: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1113 - val_loss: 2.2511 - 149ms/epoch - 25ms/step
# Epoch 322/1500
#
# Epoch 322: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0850 - val_loss: 22.2367 - 160ms/epoch - 27ms/step
# Epoch 323/1500
#
# Epoch 323: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0841 - val_loss: 67.4873 - 141ms/epoch - 23ms/step
# Epoch 324/1500
#
# Epoch 324: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0855 - val_loss: 4.3897 - 156ms/epoch - 26ms/step
# Epoch 325/1500
#
# Epoch 325: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0805 - val_loss: 2.6700 - 156ms/epoch - 26ms/step
# Epoch 326/1500
#
# Epoch 326: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1395 - val_loss: 1.4976 - 143ms/epoch - 24ms/step
# Epoch 327/1500
#
# Epoch 327: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1186 - val_loss: 1.1963 - 156ms/epoch - 26ms/step
# Epoch 328/1500
#
# Epoch 328: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1105 - val_loss: 2.0178 - 156ms/epoch - 26ms/step
# Epoch 329/1500
#
# Epoch 329: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1398 - val_loss: 1904.7374 - 146ms/epoch - 24ms/step
# Epoch 330/1500
#
# Epoch 330: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1816 - val_loss: 2.7913 - 156ms/epoch - 26ms/step
# Epoch 331/1500
#
# Epoch 331: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1493 - val_loss: 1.8443 - 156ms/epoch - 26ms/step
# Epoch 332/1500
#
# Epoch 332: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1215 - val_loss: 134.2022 - 143ms/epoch - 24ms/step
# Epoch 333/1500
#
# Epoch 333: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1287 - val_loss: 106299.4609 - 156ms/epoch - 26ms/step
# Epoch 334/1500
#
# Epoch 334: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1126 - val_loss: 52189.3594 - 156ms/epoch - 26ms/step
# Epoch 335/1500
#
# Epoch 335: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1046 - val_loss: 73727.2422 - 141ms/epoch - 23ms/step
# Epoch 336/1500
#
# Epoch 336: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0946 - val_loss: 374516.3750 - 148ms/epoch - 25ms/step
# Epoch 337/1500
#
# Epoch 337: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0843 - val_loss: 254250.0625 - 141ms/epoch - 23ms/step
# Epoch 338/1500
#
# Epoch 338: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0871 - val_loss: 63529.4648 - 141ms/epoch - 23ms/step
# Epoch 339/1500
#
# Epoch 339: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1146 - val_loss: 58862.0469 - 159ms/epoch - 26ms/step
# Epoch 340/1500
#
# Epoch 340: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0932 - val_loss: 1.5840 - 141ms/epoch - 23ms/step
# Epoch 341/1500
#
# Epoch 341: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.1087 - val_loss: 1.3660 - 157ms/epoch - 26ms/step
# Epoch 342/1500
#
# Epoch 342: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0979 - val_loss: 1.1052 - 161ms/epoch - 27ms/step
# Epoch 343/1500
#
# Epoch 343: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0869 - val_loss: 305.9276 - 144ms/epoch - 24ms/step
# Epoch 344/1500
#
# Epoch 344: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0865 - val_loss: 1.4481 - 159ms/epoch - 26ms/step
# Epoch 345/1500
#
# Epoch 345: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0791 - val_loss: 2.3492 - 156ms/epoch - 26ms/step
# Epoch 346/1500
#
# Epoch 346: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0647 - val_loss: 1.8561 - 150ms/epoch - 25ms/step
# Epoch 347/1500
#
# Epoch 347: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0744 - val_loss: 1.0466 - 149ms/epoch - 25ms/step
# Epoch 348/1500
#
# Epoch 348: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0687 - val_loss: 1.0332 - 156ms/epoch - 26ms/step
# Epoch 349/1500
#
# Epoch 349: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0778 - val_loss: 1.1482 - 156ms/epoch - 26ms/step
# Epoch 350/1500
#
# Epoch 350: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0682 - val_loss: 1.3889 - 156ms/epoch - 26ms/step
# Epoch 351/1500
#
# Epoch 351: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0673 - val_loss: 2.1394 - 141ms/epoch - 23ms/step
# Epoch 352/1500
#
# Epoch 352: val_loss did not improve from 0.82770
# 6/6 - 0s - loss: 0.0706 - val_loss: 1.9838 - 159ms/epoch - 26ms/step
# Epoch 353/1500
#
# Epoch 353: val_loss did not improve from 0.82770
# ...
# 6/6 - 0s - loss: 0.0462 - val_loss: 314.9765 - 146ms/epoch - 24ms/step
# Epoch 1385/1500
#
# Epoch 1385: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0457 - val_loss: 121.3097 - 154ms/epoch - 26ms/step
# Epoch 1386/1500
#
# Epoch 1386: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0469 - val_loss: 274.4704 - 156ms/epoch - 26ms/step
# Epoch 1387/1500
#
# Epoch 1387: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0455 - val_loss: 413.6784 - 156ms/epoch - 26ms/step
# Epoch 1388/1500
#
# Epoch 1388: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0469 - val_loss: 700.8232 - 159ms/epoch - 26ms/step
# Epoch 1389/1500
#
# Epoch 1389: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0451 - val_loss: 2544.6282 - 156ms/epoch - 26ms/step
# Epoch 1390/1500
#
# Epoch 1390: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0451 - val_loss: 1.4880 - 156ms/epoch - 26ms/step
# Epoch 1391/1500
#
# Epoch 1391: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0436 - val_loss: 1.0783 - 143ms/epoch - 24ms/step
# Epoch 1392/1500
#
# Epoch 1392: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0485 - val_loss: 1.0038 - 156ms/epoch - 26ms/step
# Epoch 1393/1500
#
# Epoch 1393: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0455 - val_loss: 0.9043 - 156ms/epoch - 26ms/step
# Epoch 1394/1500
#
# Epoch 1394: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0468 - val_loss: 4.0299 - 156ms/epoch - 26ms/step
# Epoch 1395/1500
#
# Epoch 1395: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0447 - val_loss: 2.4558 - 152ms/epoch - 25ms/step
# Epoch 1396/1500
#
# Epoch 1396: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0450 - val_loss: 9.6271 - 141ms/epoch - 23ms/step
# Epoch 1397/1500
#
# Epoch 1397: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0441 - val_loss: 61.8633 - 156ms/epoch - 26ms/step
# Epoch 1398/1500
#
# Epoch 1398: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0483 - val_loss: 1.0134 - 154ms/epoch - 26ms/step
# Epoch 1399/1500
#
# Epoch 1399: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0497 - val_loss: 271.5079 - 156ms/epoch - 26ms/step
# Epoch 1400/1500
#
# Epoch 1400: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0449 - val_loss: 1.7273 - 156ms/epoch - 26ms/step
# Epoch 1401/1500
#
# Epoch 1401: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0437 - val_loss: 1.0513 - 157ms/epoch - 26ms/step
# Epoch 1402/1500
#
# Epoch 1402: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0446 - val_loss: 1.2190 - 156ms/epoch - 26ms/step
# Epoch 1403/1500
#
# Epoch 1403: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0443 - val_loss: 1.1785 - 141ms/epoch - 23ms/step
# Epoch 1404/1500
#
# Epoch 1404: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0454 - val_loss: 2.3199 - 158ms/epoch - 26ms/step
# Epoch 1405/1500
#
# Epoch 1405: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0440 - val_loss: 1.2842 - 156ms/epoch - 26ms/step
# Epoch 1406/1500
#
# Epoch 1406: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0447 - val_loss: 2.2646 - 156ms/epoch - 26ms/step
# Epoch 1407/1500
#
# Epoch 1407: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0454 - val_loss: 2.0234 - 156ms/epoch - 26ms/step
# Epoch 1408/1500
#
# Epoch 1408: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0434 - val_loss: 2.3081 - 158ms/epoch - 26ms/step
# Epoch 1409/1500
#
# Epoch 1409: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0475 - val_loss: 1.4779 - 141ms/epoch - 23ms/step
# Epoch 1410/1500
#
# Epoch 1410: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0458 - val_loss: 1.0841 - 141ms/epoch - 23ms/step
# Epoch 1411/1500
#
# Epoch 1411: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0457 - val_loss: 1.2774 - 161ms/epoch - 27ms/step
# Epoch 1412/1500
#
# Epoch 1412: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0437 - val_loss: 1.3327 - 156ms/epoch - 26ms/step
# Epoch 1413/1500
#
# Epoch 1413: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0449 - val_loss: 1.6195 - 141ms/epoch - 23ms/step
# Epoch 1414/1500
#
# Epoch 1414: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0473 - val_loss: 1.4511 - 159ms/epoch - 27ms/step
# Epoch 1415/1500
#
# Epoch 1415: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0454 - val_loss: 1.1611 - 155ms/epoch - 26ms/step
# Epoch 1416/1500
#
# Epoch 1416: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0478 - val_loss: 1.2902 - 156ms/epoch - 26ms/step
# Epoch 1417/1500
#
# Epoch 1417: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0588 - val_loss: 1.3068 - 158ms/epoch - 26ms/step
# Epoch 1418/1500
#
# Epoch 1418: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0554 - val_loss: 1.4180 - 156ms/epoch - 26ms/step
# Epoch 1419/1500
#
# Epoch 1419: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0574 - val_loss: 57249.3945 - 156ms/epoch - 26ms/step
# Epoch 1420/1500
#
# Epoch 1420: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0563 - val_loss: 78297.3828 - 156ms/epoch - 26ms/step
# Epoch 1421/1500
#
# Epoch 1421: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0528 - val_loss: 1.3346 - 142ms/epoch - 24ms/step
# Epoch 1422/1500
#
# Epoch 1422: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0521 - val_loss: 2.3085 - 141ms/epoch - 23ms/step
# Epoch 1423/1500
#
# Epoch 1423: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0491 - val_loss: 1.5775 - 141ms/epoch - 23ms/step
# Epoch 1424/1500
#
# Epoch 1424: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0470 - val_loss: 1.6749 - 156ms/epoch - 26ms/step
# Epoch 1425/1500
#
# Epoch 1425: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0484 - val_loss: 1.4492 - 168ms/epoch - 28ms/step
# Epoch 1426/1500
#
# Epoch 1426: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0471 - val_loss: 1.4884 - 156ms/epoch - 26ms/step
# Epoch 1427/1500
#
# Epoch 1427: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0486 - val_loss: 1.4484 - 157ms/epoch - 26ms/step
# Epoch 1428/1500
#
# Epoch 1428: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0466 - val_loss: 1.1915 - 141ms/epoch - 23ms/step
# Epoch 1429/1500
#
# Epoch 1429: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0451 - val_loss: 1.2094 - 156ms/epoch - 26ms/step
# Epoch 1430/1500
#
# Epoch 1430: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0463 - val_loss: 1.3135 - 156ms/epoch - 26ms/step
# Epoch 1431/1500
#
# Epoch 1431: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0417 - val_loss: 1.6671 - 158ms/epoch - 26ms/step
# Epoch 1432/1500
#
# Epoch 1432: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0478 - val_loss: 34.5570 - 156ms/epoch - 26ms/step
# Epoch 1433/1500
#
# Epoch 1433: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0445 - val_loss: 7071.5645 - 156ms/epoch - 26ms/step
# Epoch 1434/1500
#
# Epoch 1434: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0428 - val_loss: 188.0940 - 145ms/epoch - 24ms/step
# Epoch 1435/1500
#
# Epoch 1435: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0557 - val_loss: 3.1736 - 141ms/epoch - 23ms/step
# Epoch 1436/1500
#
# Epoch 1436: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0446 - val_loss: 2.0183 - 156ms/epoch - 26ms/step
# Epoch 1437/1500
#
# Epoch 1437: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0539 - val_loss: 1.5829 - 141ms/epoch - 23ms/step
# Epoch 1438/1500
#
# Epoch 1438: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0533 - val_loss: 1.4204 - 162ms/epoch - 27ms/step
# Epoch 1439/1500
#
# Epoch 1439: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0534 - val_loss: 821.2677 - 156ms/epoch - 26ms/step
# Epoch 1440/1500
#
# Epoch 1440: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0573 - val_loss: 1.3448 - 156ms/epoch - 26ms/step
# Epoch 1441/1500
#
# Epoch 1441: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0471 - val_loss: 2.0205 - 146ms/epoch - 24ms/step
# Epoch 1442/1500
#
# Epoch 1442: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0540 - val_loss: 2.4510 - 156ms/epoch - 26ms/step
# Epoch 1443/1500
#
# Epoch 1443: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0607 - val_loss: 2893.4172 - 156ms/epoch - 26ms/step
# Epoch 1444/1500
#
# Epoch 1444: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0511 - val_loss: 24249.9883 - 141ms/epoch - 23ms/step
# Epoch 1445/1500
#
# Epoch 1445: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0499 - val_loss: 98111.3281 - 141ms/epoch - 23ms/step
# Epoch 1446/1500
#
# Epoch 1446: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0510 - val_loss: 57086.6484 - 141ms/epoch - 23ms/step
# Epoch 1447/1500
#
# Epoch 1447: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0512 - val_loss: 11603.1416 - 156ms/epoch - 26ms/step
# Epoch 1448/1500
#
# Epoch 1448: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0488 - val_loss: 2351.4678 - 157ms/epoch - 26ms/step
# Epoch 1449/1500
#
# Epoch 1449: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0546 - val_loss: 1630.4375 - 156ms/epoch - 26ms/step
# Epoch 1450/1500
#
# Epoch 1450: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0510 - val_loss: 1069.1615 - 141ms/epoch - 23ms/step
# Epoch 1451/1500
#
# Epoch 1451: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0512 - val_loss: 698.7648 - 157ms/epoch - 26ms/step
# Epoch 1452/1500
#
# Epoch 1452: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0511 - val_loss: 2.2177 - 156ms/epoch - 26ms/step
# Epoch 1453/1500
#
# Epoch 1453: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0504 - val_loss: 229.2862 - 141ms/epoch - 24ms/step
# Epoch 1454/1500
#
# Epoch 1454: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0516 - val_loss: 1.2645 - 156ms/epoch - 26ms/step
# Epoch 1455/1500
#
# Epoch 1455: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0527 - val_loss: 2.6036 - 156ms/epoch - 26ms/step
# Epoch 1456/1500
#
# Epoch 1456: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0508 - val_loss: 1.6304 - 156ms/epoch - 26ms/step
# Epoch 1457/1500
#
# Epoch 1457: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0515 - val_loss: 22689.2246 - 156ms/epoch - 26ms/step
# Epoch 1458/1500
#
# Epoch 1458: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0493 - val_loss: 1530.2075 - 159ms/epoch - 26ms/step
# Epoch 1459/1500
#
# Epoch 1459: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0452 - val_loss: 446.2658 - 156ms/epoch - 26ms/step
# Epoch 1460/1500
#
# Epoch 1460: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0517 - val_loss: 20.0016 - 141ms/epoch - 23ms/step
# Epoch 1461/1500
#
# Epoch 1461: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0446 - val_loss: 48.0928 - 160ms/epoch - 27ms/step
# Epoch 1462/1500
#
# Epoch 1462: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0475 - val_loss: 2005.9799 - 156ms/epoch - 26ms/step
# Epoch 1463/1500
#
# Epoch 1463: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0493 - val_loss: 14462.6982 - 159ms/epoch - 27ms/step
# Epoch 1464/1500
#
# Epoch 1464: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0432 - val_loss: 12586.3555 - 143ms/epoch - 24ms/step
# Epoch 1465/1500
#
# Epoch 1465: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0452 - val_loss: 356.0258 - 156ms/epoch - 26ms/step
# Epoch 1466/1500
#
# Epoch 1466: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0459 - val_loss: 1098.5250 - 141ms/epoch - 24ms/step
# Epoch 1467/1500
#
# Epoch 1467: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0464 - val_loss: 1303.6350 - 156ms/epoch - 26ms/step
# Epoch 1468/1500
#
# Epoch 1468: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0469 - val_loss: 1356.2594 - 149ms/epoch - 25ms/step
# Epoch 1469/1500
#
# Epoch 1469: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0467 - val_loss: 12724.2422 - 156ms/epoch - 26ms/step
# Epoch 1470/1500
#
# Epoch 1470: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0477 - val_loss: 5371.4780 - 156ms/epoch - 26ms/step
# Epoch 1471/1500
#
# Epoch 1471: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0518 - val_loss: 921.0684 - 158ms/epoch - 26ms/step
# Epoch 1472/1500
#
# Epoch 1472: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0487 - val_loss: 18.2129 - 141ms/epoch - 23ms/step
# Epoch 1473/1500
#
# Epoch 1473: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0453 - val_loss: 50.6102 - 141ms/epoch - 23ms/step
# Epoch 1474/1500
#
# Epoch 1474: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0462 - val_loss: 2767.1292 - 141ms/epoch - 24ms/step
# Epoch 1475/1500
#
# Epoch 1475: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0461 - val_loss: 184.0697 - 166ms/epoch - 28ms/step
# Epoch 1476/1500
#
# Epoch 1476: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0441 - val_loss: 37.0365 - 156ms/epoch - 26ms/step
# Epoch 1477/1500
#
# Epoch 1477: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0430 - val_loss: 240.0044 - 141ms/epoch - 23ms/step
# Epoch 1478/1500
#
# Epoch 1478: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0433 - val_loss: 243.4391 - 157ms/epoch - 26ms/step
# Epoch 1479/1500
#
# Epoch 1479: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0422 - val_loss: 4.1832 - 156ms/epoch - 26ms/step
# Epoch 1480/1500
#
# Epoch 1480: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0445 - val_loss: 2.3204 - 156ms/epoch - 26ms/step
# Epoch 1481/1500
#
# Epoch 1481: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0421 - val_loss: 10.5699 - 157ms/epoch - 26ms/step
# Epoch 1482/1500
#
# Epoch 1482: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0436 - val_loss: 41.9397 - 156ms/epoch - 26ms/step
# Epoch 1483/1500
#
# Epoch 1483: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0440 - val_loss: 29.8655 - 156ms/epoch - 26ms/step
# Epoch 1484/1500
#
# Epoch 1484: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0437 - val_loss: 10.8826 - 159ms/epoch - 27ms/step
# Epoch 1485/1500
#
# Epoch 1485: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0407 - val_loss: 1.8322 - 156ms/epoch - 26ms/step
# Epoch 1486/1500
#
# Epoch 1486: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0431 - val_loss: 40.7721 - 156ms/epoch - 26ms/step
# Epoch 1487/1500
#
# Epoch 1487: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0429 - val_loss: 42.3470 - 141ms/epoch - 23ms/step
# Epoch 1488/1500
#
# Epoch 1488: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0414 - val_loss: 12.5434 - 154ms/epoch - 26ms/step
# Epoch 1489/1500
#
# Epoch 1489: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0455 - val_loss: 147.8633 - 156ms/epoch - 26ms/step
# Epoch 1490/1500
#
# Epoch 1490: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0430 - val_loss: 4.5023 - 141ms/epoch - 23ms/step
# Epoch 1491/1500
#
# Epoch 1491: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0413 - val_loss: 1.0514 - 145ms/epoch - 24ms/step
# Epoch 1492/1500
#
# Epoch 1492: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0426 - val_loss: 0.9492 - 156ms/epoch - 26ms/step
# Epoch 1493/1500
#
# Epoch 1493: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0442 - val_loss: 2.6005 - 141ms/epoch - 23ms/step
# Epoch 1494/1500
#
# Epoch 1494: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0421 - val_loss: 19.6165 - 160ms/epoch - 27ms/step
# Epoch 1495/1500
#
# Epoch 1495: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0430 - val_loss: 76.6858 - 156ms/epoch - 26ms/step
# Epoch 1496/1500
#
# Epoch 1496: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0445 - val_loss: 10.6435 - 156ms/epoch - 26ms/step
# Epoch 1497/1500
#
# Epoch 1497: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0439 - val_loss: 1.1372 - 141ms/epoch - 23ms/step
# Epoch 1498/1500
#
# Epoch 1498: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0460 - val_loss: 158.8678 - 156ms/epoch - 26ms/step
# Epoch 1499/1500
#
# Epoch 1499: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0432 - val_loss: 194.8520 - 172ms/epoch - 29ms/step
# Epoch 1500/1500
#
# Epoch 1500: val_loss did not improve from 0.79466
# 6/6 - 0s - loss: 0.0441 - val_loss: 1.0332 - 159ms/epoch - 26ms/step

# %%
plot_loss(history)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 plot_loss(history)
#
# NameError: name 'history' is not defined

# %%
# load model
model_name = "silica_CNN_cut_psd_exp.keras"
model = tf.keras.models.load_model(f'data/models/{model_name}', custom_objects={'abs': tf.math.abs, 'custom_loss': custom_loss, 'ConstrainedOutputLayer': ConstrainedOutputLayer})

# %%
#tf.keras.models.save_model(model,'data/models/silica_CNN3.keras')

# %%
# prediction = model.evaluate(np.array(x_test), np.array(y_test))
prediction = model.predict(np.array(x_test_exp))
model.evaluate(np.array(x_test), np.array(y_test), verbose=2)
# Out:
# 107/107 [==============================] - 0s 2ms/step
# 107/107 - 0s - loss: 25.3987 - 168ms/epoch - 2ms/step
# 25.39873695373535

# %%
# test on x_train
def fetch_prediction(prediction):
    return prediction[:128]

pore_widths = np.load("data/initial kernels/Size_Kernel_Silica_Adsorption.npy")
pressures = np.load("data/initial kernels/Pressure_Silica.npy")
NX, NY = 3, 4
figure, axis = plt.subplots(NX, NY)
for i in range(NX):
    for j in range(NY):
        k = np.random.randint(0, len(x_test_exp)) 
        # axis[i, j].plot(pore_widths , fetch_prediction(prediction[k]), marker=".", label=f"Prediction")
        # axis[i, j].plot(pore_widths , y_test[k], marker=".", label="Real distribution")

        axis[i, j].grid()
        axis[i, j].set_xlabel("nm",fontsize=8)
        axis[i, j].plot(pore_widths, fetch_prediction(prediction[k]), marker=".", label=f"Model PSD")
        axis[i, j].plot(pore_widths, y_test_exp[k], marker=".", label="PSD")
        
        iso_axis = axis[i, j].twiny()
        iso_axis.set_xlabel("P/P$^0$",fontsize=8)
        iso_axis.plot(pressures[:-10], x_test_exp[k], label="Isotherm", color = 'green')
        kernel = (data_sorb.T[:-10])
        iso_axis.plot(pressures[:-10], np.dot(kernel, prediction[k][:128]), label="Isotherm by PSD", color="red")
        axis[i, j].set_title(f"№ {k}")
        axis[i, j].title.set_size(10)
plt.subplots_adjust(hspace=0.6, right=0.95, left=0.05, bottom=0.05, top=0.9)
plt.legend()
axis[0, 0].legend()
plt.show()

# %%
math_psds = [fit_linear(x_test_exp[i], kernel.T, 0).x for i in range(len(x_test_exp))]
restored_isotherms = [np.dot(kernel, psd) for psd in math_psds]

# %%
from tools import model_tester
#importlib.reload(model_tester)
    
model_tester.plot_testing_graphs(prediction, x_test_exp, restored_isotherms, kernel, model_name)

# %%
error_lst_math, roughness_lst_math = model_tester.calculate_error_for_math(x_test_exp, restored_isotherms=restored_isotherms)
kde_x_math, kde_error_math, _  = model_tester.calculate_kde_data(error_lst_math, stop=150)
print(model_name)
print("median error:", np.median(error_lst_math))
# Out:
# silica_CNN_cut_psd_exp.keras
# average error: 11.554572714305223

# %%
plt.plot(kde_x, kde_roughness, label=model_name)
#plt.plot(kde_x_math, kde_error_math, label="math")
plot()

# %%
plt.plot(kde_x, kde_error, label=model_name)
plt.plot(kde_x_math, kde_error_math, label="math")
plot()

# %%
# test with test Generator
from tools import TestApp

gen = Generator(path_s="data/initial kernels/Kernel_Silica_Adsorption.npy",
                path_d="data/initial kernels/Kernel_Silica_Desorption.npy",
                path_p_d="data/initial kernels/Pressure_Silica.npy",
                path_p_s="data/initial kernels/Pressure_Silica.npy",
                path_a="data/initial kernels/Size_Kernel_Silica_Adsorption.npy"
                )
# gen = Generator(path_s="data/initial kernels/Kernel_Carbon_Adsorption.npy",
#                               path_d="data/initial kernels/Kernel_Carbon_Desorption.npy",
#                               path_p_d="data/initial kernels/Pressure_Carbon.npy",
#                               path_p_s="data/initial kernels/Pressure_Carbon.npy",
#                               path_a="data/initial kernels/Size_Kernel_Carbon_Adsorption.npy"
#                             )

#TestApp.App(model, gen)

# %%
exp_file_list = ["MCM-41", "SBA-15", "SBA-16", "MIL-101", "MIL-101_2", "DUT-49", "FDM-4", "PCN-333", "PCN-777",
                 "MIL-100"]

p_exp_list = []
n_s_exp_raw_list = []
for exp_file_name in exp_file_list:
    data = pd.read_csv(f"data/real/{exp_file_name}.txt", header=None)
    # p_exp_list.append(data.iloc[:,1].to_numpy())
    # n_s_exp_raw_list.append(data.iloc[:,3].to_numpy())
    p_exp_list.append(data.iloc[:, 1].to_numpy())
    n_s_exp_raw_list.append(data.iloc[:, 3].to_numpy())

# %%
j = 2
plt.plot(p_exp_list[j], n_s_exp_raw_list[j], marker=".", label=exp_file_list[j])
plot()

# %%
# интерполируем экспериментальную изотерму под давления кернала
n_s_exp_list = []
for i in range(len(p_exp_list)):
    n_s_exp_list.append(np.interp(gen.pressures_s[77:367], p_exp_list[i], n_s_exp_raw_list[i]))

# %%
j = 2
plt.plot(gen.pressures_s[77:367], n_s_exp_list[j], marker=".", label=exp_file_list[j])
plot()

# %%
n_s_exp_for_net_list = [pre_process_isotherm(np.copy(n_s_exp), scale=False) for n_s_exp in n_s_exp_list]
fit_exp_list = [model.predict(np.array([n_s_exp_for_net])).T for n_s_exp_for_net in n_s_exp_for_net_list]
fit_exp_list = [fetch_prediction(i) for i in fit_exp_list]
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[22], line 2
#       1 n_s_exp_for_net_list = [pre_process_isotherm(np.copy(n_s_exp), scale=False) for n_s_exp in n_s_exp_list]
# ----> 2 fit_exp_list = [model.predict(np.array([n_s_exp_for_net])).T for n_s_exp_for_net in n_s_exp_for_net_list]
#       3 fit_exp_list = [fetch_prediction(i) for i in fit_exp_list]
#
# Cell In[22], line 2, in <listcomp>(.0)
#       1 n_s_exp_for_net_list = [pre_process_isotherm(np.copy(n_s_exp), scale=False) for n_s_exp in n_s_exp_list]
# ----> 2 fit_exp_list = [model.predict(np.array([n_s_exp_for_net])).T for n_s_exp_for_net in n_s_exp_for_net_list]
#       3 fit_exp_list = [fetch_prediction(i) for i in fit_exp_list]
#
# File ~\anaconda3\envs\py310\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'CNN/f1/Reshape' defined at (most recent call last):
#     File "C:\Users\user\anaconda3\envs\py310\lib\runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\user\anaconda3\envs\py310\lib\runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#       app.launch_new_instance()
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#       app.start()
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\user\anaconda3\envs\py310\lib\asyncio\base_events.py", line 603, in run_forever
#       self._run_once()
#     File "C:\Users\user\anaconda3\envs\py310\lib\asyncio\base_events.py", line 1909, in _run_once
#       handle._run()
#     File "C:\Users\user\anaconda3\envs\py310\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#       await dispatch(*args)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\ipykernel\kernelbase.py", line 487, in advance_eventloop
#       eventloop(self)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\ipykernel\eventloops.py", line 309, in loop_tk
#       kernel.app_wrapper.start()
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\ipykernel\eventloops.py", line 306, in start
#       self.app.mainloop()
#     File "C:\Users\user\anaconda3\envs\py310\lib\tkinter\__init__.py", line 1458, in mainloop
#       self.tk.mainloop(n)
#     File "C:\Users\user\anaconda3\envs\py310\lib\tkinter\__init__.py", line 1921, in __call__
#       return self.func(*args)
#     File "C:\Users\user\anaconda3\envs\py310\lib\tkinter\__init__.py", line 839, in callit
#       func(*args)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\ipykernel\eventloops.py", line 299, in on_timer
#       loop.run_until_complete(self.func())
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\nest_asyncio.py", line 92, in run_until_complete
#       self._run_once()
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\nest_asyncio.py", line 133, in _run_once
#       handle._run()
#     File "C:\Users\user\anaconda3\envs\py310\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\user\anaconda3\envs\py310\lib\asyncio\tasks.py", line 232, in __step
#       result = coro.send(None)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\ipykernel\kernelbase.py", line 520, in do_one_iteration
#       await self.process_one(wait=False)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#       await dispatch(*args)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#       await result
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#       await super().execute_request(stream, ident, parent)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#       res = shell.run_cell(
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#       result = self._run_cell(
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#       result = runner(coro)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\user\AppData\Local\Temp\ipykernel_10012\2050301347.py", line 2, in <module>
#       fit_exp_list = [model.predict(np.array([n_s_exp_for_net])).T for n_s_exp_for_net in n_s_exp_for_net_list]
#     File "C:\Users\user\AppData\Local\Temp\ipykernel_10012\2050301347.py", line 2, in <listcomp>
#       fit_exp_list = [model.predict(np.array([n_s_exp_for_net])).T for n_s_exp_for_net in n_s_exp_for_net_list]
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\keras\engine\training.py", line 2253, in predict
#       tmp_batch_outputs = self.predict_function(iterator)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\keras\engine\training.py", line 2041, in predict_function
#       return step_function(self, iterator)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\keras\engine\training.py", line 2027, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\keras\engine\training.py", line 2015, in run_step
#       outputs = model.predict_step(data)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\keras\engine\training.py", line 1983, in predict_step
#       return self(x, training=False)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\user\anaconda3\envs\py310\lib\site-packages\keras\layers\reshaping\flatten.py", line 104, in call
#       return tf.reshape(inputs, flattened_shape)
# Node: 'CNN/f1/Reshape'
# Input to reshape is a tensor with 1280 values, but the requested shape requires a multiple of 1792
# 	 [[{{node CNN/f1/Reshape}}]] [Op:__inference_predict_function_3214]

# %%
NX, NY = 3, 4
figure, axis = plt.subplots(NX, NY)
k = 0
for i in range(NX):
    for j in range(NY):
        x_scale_factor = max(gen.a_array) / max(p_exp_list[k])
        y_scale_factor = max(fit_exp_list[k]) / max(n_s_exp_raw_list[k])
        axis[i, j].plot(pore_widths, fit_exp_list[k], marker=".", label=f"Distribution")
        axis[i, j].plot(p_exp_list[k] * x_scale_factor, n_s_exp_raw_list[k],
                        label=f"{exp_file_list[k]}", marker=".")
        
        kernal = (data_sorb.T[40:])
        axis[i, j].plot(gen.pressures_s[40:458]* x_scale_factor, np.dot(kernal, fit_exp_list[k]), label="Isotherm by distribution")
        
        axis[i, j].set_title(f"max at {round(gen.a_array[np.argmax(fit_exp_list[k])], 2)} nm")
        axis[i, j].title.set_size(12)
        axis[i, j].legend(loc="upper right")
        axis[i, j].grid()
        k += 1
        if k >= len(fit_exp_list):
            break
plt.subplots_adjust(hspace=0.6, right=0.95, left=0.05, bottom=0.05, top=0.95)
plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 7
#       5 for j in range(NY):
#       6     x_scale_factor = max(gen.a_array) / max(p_exp_list[k])
# ----> 7     y_scale_factor = max(fit_exp_list[k]) / max(n_s_exp_raw_list[k])
#       8     axis[i, j].plot(pore_widths, fit_exp_list[k], marker=".", label=f"Distribution")
#       9     axis[i, j].plot(p_exp_list[k] * x_scale_factor, n_s_exp_raw_list[k],
#      10                     label=f"{exp_file_list[k]}", marker=".")
#
# NameError: name 'fit_exp_list' is not defined

# %%
### Classic
import inverse

kernel = np.load("data/initial kernels/Kernel_Silica_Adsorption.npy")

### normalize on size
# a_array = np.load("data/initial kernels/Size_Kernel_Silica_Adsorption.npy")
# for i in range(len(a_array)):
#     kernel[i] /= a_array[i]
#     kernel[i] /= a_array[i]
###

cut_kernel = []
for i in range(len(kernel)):
    cut_kernel.append(kernel[i][40:458])
cut_kernel = np.array(cut_kernel)
fit_classic_list = [inverse.fit_SLSQP(adsorption=n_s, kernel=cut_kernel, a_array=pore_widths) for n_s in n_s_exp_list]

# %%
from matplotlib import animation

importlib.reload(inverse)


def create_regularization_animation(file):
    fig, ax = plt.subplots()
    fig.set_size_inches(10, 5, True)
    fit_classic = inverse.fit_SLSQP(adsorption=n_s_exp_list[2], kernel=cut_kernel, a_array=pore_widths, alpha=0)
    line1, = ax.plot(pore_widths[:-30], fit_classic.x[:-30], marker=".", label=f"a = {0}")

    y_scale_factor = max(fit_classic.x) / max(fit_exp_list[2])
    #plt.plot(pore_widths, fit_exp_list[2] * y_scale_factor, marker=".", label=f"Суррогатная модель")

    ax.set_ylabel("Объем пор, $см^3$/ нм * г")
    ax.set_xlabel("Размер пор, нм")

    L = plt.legend(loc=1)  # Define legend objects

    def update(frame):
        a = frame / 4 + 2
        fit_classic = inverse.fit_SLSQP(adsorption=n_s_exp_list[2], kernel=cut_kernel, a_array=pore_widths, alpha=a)
        line1.set_ydata(fit_classic.x[:-30])
        L.get_texts()[0].set_text(
            f"Распределение пор по размерам, параметр регуляризации α = {round(a-2,1)}")  # Update label each at frame
        return line1,

    ani = animation.FuncAnimation(fig=fig, func=update, frames=100, interval=100)
    writervideo = animation.FFMpegWriter(fps=30)
    ani.save(file, writer=writervideo, dpi=200)
    plt.grid()
    plt.show()
create_regularization_animation("SBA-16_regularization.mp4")
def plot_regularization_graphs():
    for a in [1, 5, 10, 50]:
        fit_classic = inverse.fit_SLSQP(adsorption=n_s_exp_list[2], kernel=cut_kernel, a_array=pore_widths, alpha=a)
        plt.plot(pore_widths, fit_classic.x, marker=".", label=f"α = {a}")
    plt.ylabel("Объем пор, $см^3$/ нм * гр")
    plt.xlabel("Размер пор, нм")
    plot()
#plot_regularization_graphs()

# %%
NX, NY = 3, 4
figure, axis = plt.subplots(NX, NY)
k = 0
for i in range(NX):
    for j in range(NY):
        x_scale_factor = max(gen.a_array) / max(p_exp_list[k])
        y_scale_factor = max(fit_classic_list[k].x) / max(n_s_exp_raw_list[k])
        y_scale_factor_net = max(fit_classic_list[k].x) / max(fit_exp_list[k])

        axis[i, j].plot(pore_widths, fit_exp_list[k] * y_scale_factor_net, marker=".", label=f"net")
        axis[i, j].plot(pore_widths, fit_classic_list[k].x, marker=".", label=f"classic")
        axis[i, j].plot(p_exp_list[k] * x_scale_factor, n_s_exp_raw_list[k] * y_scale_factor,
                        label=f"{exp_file_list[k]}", marker=".")
        axis[i, j].set_title(f"max at {round(gen.a_array[np.argmax(fit_classic_list[k].x)], 2)} nm")
        axis[i, j].title.set_size(12)
        axis[i, j].legend(loc="upper right")
        axis[i, j].grid()
        k += 1
        if k >= len(fit_exp_list):
            break
plt.subplots_adjust(hspace=0.6, right=0.95, left=0.05, bottom=0.05, top=0.95)
plot()

# %%
### Classic
import inverse

kernel = np.load("data/initial kernels/Kernel_Silica_Adsorption.npy")

### normalize on size
# a_array = np.load("data/initial kernels/Size_Kernel_Silica_Adsorption.npy")
# for i in range(len(a_array)):
#     kernel[i] /= a_array[i]
#     kernel[i] /= a_array[i]
###

cut_kernel = []
for i in range(len(kernel)):
    cut_kernel.append(kernel[i][40:458])
cut_kernel = np.array(cut_kernel)
fit_classic_list = [inverse.fit_SLSQP(adsorption=n_s, kernel=cut_kernel, a_array=pore_widths) for n_s in n_s_exp_list]

# %%
from matplotlib import animation

importlib.reload(inverse)


def create_regularization_animation(file):
    fig, ax = plt.subplots()
    fig.set_size_inches(10, 5, True)
    fit_classic = inverse.fit_SLSQP(adsorption=n_s_exp_list[2], kernel=cut_kernel, a_array=pore_widths, alpha=0)
    line1, = ax.plot(pore_widths[:-30], fit_classic.x[:-30], marker=".", label=f"a = {0}")

    y_scale_factor = max(fit_classic.x) / max(fit_exp_list[2])
    #plt.plot(pore_widths, fit_exp_list[2] * y_scale_factor, marker=".", label=f"Суррогатная модель")

    ax.set_ylabel("Объем пор, $см^3$/ нм * г")
    ax.set_xlabel("Размер пор, нм")

    L = plt.legend(loc=1)  # Define legend objects

    def update(frame):
        a = frame / 4 + 2
        fit_classic = inverse.fit_SLSQP(adsorption=n_s_exp_list[2], kernel=cut_kernel, a_array=pore_widths, alpha=a)
        line1.set_ydata(fit_classic.x[:-30])
        L.get_texts()[0].set_text(
            f"Распределение пор по размерам, параметр регуляризации α = {round(a-2,1)}")  # Update label each at frame
        return line1,

    ani = animation.FuncAnimation(fig=fig, func=update, frames=100, interval=100)
    writervideo = animation.FFMpegWriter(fps=30)
    ani.save(file, writer=writervideo, dpi=200)
    plt.grid()
    plt.show()
create_regularization_animation("SBA-16_regularization.mp4")
def plot_regularization_graphs():
    for a in [1, 5, 10, 50]:
        fit_classic = inverse.fit_SLSQP(adsorption=n_s_exp_list[2], kernel=cut_kernel, a_array=pore_widths, alpha=a)
        plt.plot(pore_widths, fit_classic.x, marker=".", label=f"α = {a}")
    plt.ylabel("Объем пор, $см^3$/ нм * гр")
    plt.xlabel("Размер пор, нм")
    plot()
#plot_regularization_graphs()

# %%
NX, NY = 3, 4
figure, axis = plt.subplots(NX, NY)
k = 0
for i in range(NX):
    for j in range(NY):
        x_scale_factor = max(gen.a_array) / max(p_exp_list[k])
        y_scale_factor = max(fit_classic_list[k].x) / max(n_s_exp_raw_list[k])
        y_scale_factor_net = max(fit_classic_list[k].x) / max(fit_exp_list[k])

        axis[i, j].plot(pore_widths, fit_exp_list[k] * y_scale_factor_net, marker=".", label=f"net")
        axis[i, j].plot(pore_widths, fit_classic_list[k].x, marker=".", label=f"classic")
        axis[i, j].plot(p_exp_list[k] * x_scale_factor, n_s_exp_raw_list[k] * y_scale_factor,
                        label=f"{exp_file_list[k]}", marker=".")
        axis[i, j].set_title(f"max at {round(gen.a_array[np.argmax(fit_classic_list[k].x)], 2)} nm")
        axis[i, j].title.set_size(12)
        axis[i, j].legend(loc="upper right")
        axis[i, j].grid()
        k += 1
        if k >= len(fit_exp_list):
            break
plt.subplots_adjust(hspace=0.6, right=0.95, left=0.05, bottom=0.05, top=0.95)
plot()

# %%
# compare net, classic, quantachrome distributions
NX, NY = 3, 4
figure, axis = plt.subplots(NX, NY)
k = 0


def calculate_isotherm_by_distribution(generator: Generator, a_array, distribution):
    generator.a_array = a_array
    generator.pore_distribution = distribution
    generator.calculate_isotherms()
    return generator.n_s


#/np.ediff1d(pore_widths, to_begin=pore_widths[0])
for i in range(NX):
    for j in range(NY):
        quantachrome_pore_size = \
            np.genfromtxt(f"data/real/quantachrome/silica/distribution/{exp_file_list[k]}.csv", delimiter=",")[1:].T[
                0] / 10 * 2  # /10 - перевод в НМ * 2 - в QH размер - Half pore width.
        quantachrome_dV = \
            np.genfromtxt(f"data/real/quantachrome/silica/distribution/{exp_file_list[k]}.csv", delimiter=",")[1:].T[3]
        # isotherm_formQC = calculate_isotherm_by_distribution(gen, pore_widths, np.interp(pore_widths, quantachrome_pore_size, quantachrome_dV))
        # y_scale_factor_QH = max(n_s_exp_raw_list[k]) / max(isotherm_formQC)
        # quantachrome_dV *= y_scale_factor_QH

        y_scale_factor_classic = max(quantachrome_dV) / max(fit_classic_list[k].x)
        y_scale_factor_net = max(quantachrome_dV) / max(fit_exp_list[k])

        axis[i, j].plot(pore_widths, fit_exp_list[k] * y_scale_factor_net, marker=".", label=f"net")
        axis[i, j].plot(pore_widths, fit_classic_list[k].x * y_scale_factor_classic, marker=".", label=f"classic")
        axis[i, j].plot(quantachrome_pore_size, quantachrome_dV, marker=".", label=f"quantachrome")
        axis[i, j].set_title(f"{exp_file_list[k]}")
        axis[i, j].title.set_size(12)
        axis[i, j].legend(loc="upper right")
        axis[i, j].grid()
        k += 1
        if k >= len(fit_exp_list):
            break
plt.subplots_adjust(hspace=0.6, right=0.95, left=0.05, bottom=0.05, top=0.95)
plot()

# %%
# plots for presentation
import matplotlib.pyplot as plt
from importlib import reload

plt = reload(plt)

k = 0

quantachrome_pore_size = \
    np.genfromtxt(f"data/real/quantachrome/silica/distribution/{exp_file_list[k]}.csv", delimiter=",")[1:].T[
        0] / 10 * 2  # /10 - перевод в НМ * 2 - в QH размер - Half pore width.
quantachrome_dV = \
    np.genfromtxt(f"data/real/quantachrome/silica/distribution/{exp_file_list[k]}.csv", delimiter=",")[1:].T[3]
# isotherm_formQC = calculate_isotherm_by_distribution(gen, pore_widths, np.interp(pore_widths, quantachrome_pore_size, quantachrome_dV))
# y_scale_factor_QH = max(n_s_exp_raw_list[k]) / max(isotherm_formQC)
# quantachrome_dV *= y_scale_factor_QH

y_scale_factor_classic = max(quantachrome_dV) / max(fit_classic_list[k].x)
y_scale_factor_net = max(quantachrome_dV) / max(fit_exp_list[k])

plt.plot(pore_widths, fit_exp_list[k] * y_scale_factor_net, marker=".", label=f"Суррогатная модель")
plt.plot(pore_widths, fit_classic_list[k].x * y_scale_factor_classic, marker=".", label=f"Математическое решение")
#plt.plot(quantachrome_pore_size, quantachrome_dV, marker=".", label=f"Математическое решение QH") 
plt.legend(loc="upper right")
plt.grid()
plt.title(f"{exp_file_list[k]}")

# plt.xscale('log')
plt.subplots_adjust(left=0.15,
                    bottom=0.133,
                    right=0.979,
                    top=0.917,
                    wspace=0.4,
                    hspace=0.4)
plt.legend()
plt.grid(True)
plt.ylabel("Объем пор, $см^3$/ нм * гр")
plt.xlabel("Размер пор, нм")
plt.show()

# %%
# plots for presentation 2
k = 3
plt.plot(p_exp_list[k], n_s_exp_raw_list[k], marker=".", color='b', label=f"{exp_file_list[k]}")
k = 9
plt.plot(p_exp_list[k], n_s_exp_raw_list[k], marker=".", color='r', label=f"{exp_file_list[k]}")
plt.legend(loc="upper right")
plt.grid()
plt.title(f"Изотермы адсорбции")

# plt.xscale('log')
plt.subplots_adjust(left=0.15,
                    bottom=0.133,
                    right=0.979,
                    top=0.917,
                    wspace=0.4,
                    hspace=0.4)
plt.legend()
plt.grid(True)
plt.ylabel("Адсорбция, $см^3$/г")
plt.xlabel("Давление, $P/P_{0}$")
plt.show()

# %%
# plots for presentation 3

fig, ax1 = plt.subplots(figsize=(6, 7))
ax1.set_xlabel("Размер пор, нм")
ax1.set_ylabel("Объем пор, $см^3$/ нм * гр")
k = 0
plt.title(f"{exp_file_list[k]}")
quantachrome_pore_size = \
    np.genfromtxt(f"data/real/quantachrome/silica/distribution/{exp_file_list[k]}.csv", delimiter=",")[1:].T[
        0] / 10 * 2  # /10 - перевод в НМ * 2 - в QH размер - Half pore width.
quantachrome_dV = \
    np.genfromtxt(f"data/real/quantachrome/silica/distribution/{exp_file_list[k]}.csv", delimiter=",")[1:].T[3]
# isotherm_formQC = calculate_isotherm_by_distribution(gen, pore_widths, np.interp(pore_widths, quantachrome_pore_size, quantachrome_dV))
# y_scale_factor_QH = max(n_s_exp_raw_list[k]) / max(isotherm_formQC)
# quantachrome_dV *= y_scale_factor_QH

y_scale_factor_classic = max(quantachrome_dV) / max(fit_classic_list[k].x)
y_scale_factor_net = max(quantachrome_dV) / max(fit_exp_list[k])

ax1.plot(pore_widths[0:100], (fit_exp_list[k] * y_scale_factor_net)[0:100], marker=".", label=f"Суррогатная модель")
ax1.plot(pore_widths[0:100], (fit_classic_list[k].x * y_scale_factor_classic)[0:100], marker=".",
         label=f"Математическое решение")
# ax1.tick_params(axis='y')
# plt.legend(loc="right")


ax2 = ax1.twinx()
ax3 = ax2.twiny()  # instantiate a second axes that shares the same x-axis
ax3.set_xlabel("Давление, $P/P_{0}$")
ax2.set_ylabel("Адсорбция, $см^3$/г")  # we already handled the x-label with ax1
ax3.plot(p_exp_list[k], n_s_exp_raw_list[k], color='g', label=f"Изотерма адсорбции")
# plt.legend(loc="right")
# 
# ax2.tick_params(axis='y')
# plt.subplots_adjust(left=0.15,
#                     bottom=0.133, 
#                     right=0.979, 
#                     top=0.917, 
#                     wspace=0.4, 
#                     hspace=0.4)

fig.tight_layout()
plt.show()

# %%
# Compare isotherms
NX, NY = 2, 3
figure, axis = plt.subplots(NX, NY)
k = 0

for i in range(NX):
    for j in range(NY):
        net_isotherm = calculate_isotherm_by_distribution(gen, pore_widths, fit_exp_list[k].T[0])
        classic_isotherm = calculate_isotherm_by_distribution(gen, pore_widths, fit_classic_list[k].x)
        quantachrome_data = np.genfromtxt(f"data/real/quantachrome/silica/fitting/{exp_file_list[k]}.csv",
                                          delimiter=",")[1:].T
        quantachrome_pore_size = \
            np.genfromtxt(f"data/real/quantachrome/silica/distribution/{exp_file_list[k]}.csv", delimiter=",")[1:].T[
                0] / 10 * 2
        quantachrome_dV = \
            np.genfromtxt(f"data/real/quantachrome/silica/distribution/{exp_file_list[k]}.csv", delimiter=",")[1:].T[3]
        quantachrome_data2 = calculate_isotherm_by_distribution(gen, pore_widths,
                                                                np.interp(pore_widths, quantachrome_pore_size,
                                                                          quantachrome_dV))

        y_scale_factor_net = max(net_isotherm) / max(n_s_exp_raw_list[k])
        y_scale_factor_classic = max(classic_isotherm) / max(n_s_exp_raw_list[k])
        y_scale_factor_quantachrome = max(quantachrome_data[1]) / max(n_s_exp_raw_list[k])
        y_scale_factor_quantachrome2 = max(quantachrome_data2) / (
            n_s_exp_raw_list[k][-1])  #max(quantachrome_data[1]) / max(n_s_exp_raw_list[k])
        print(1 / y_scale_factor_quantachrome2)

        axis[i, j].plot(p_exp_list[k], n_s_exp_raw_list[k], label="real")
        axis[i, j].plot(gen.pressures_s, classic_isotherm / y_scale_factor_classic, marker=".", label=f"classic")
        axis[i, j].plot(gen.pressures_s, net_isotherm / y_scale_factor_net, label="net")
        # axis[i, j].plot(quantachrome_data[0], quantachrome_data[1]/y_scale_factor_quantachrome, label="quantachrome")
        # axis[i, j].plot(gen.pressures_s, quantachrome_data2/y_scale_factor_quantachrome2, label="quantachrome_from_kernal")
        axis[i, j].set_title(f"{exp_file_list[k]}")
        axis[i, j].legend(loc="lower right")
        axis[i, j].grid()
        k += 1
        if k >= len(fit_exp_list):
            break
plt.subplots_adjust(hspace=0.6, right=0.95, left=0.05, bottom=0.05, top=0.95)
plot()

# %%
#QUANTACHROME
data = np.genfromtxt("data/real/quantachrome/silica/distribution/MIL-101.csv", delimiter=",")[1:].T[0]
